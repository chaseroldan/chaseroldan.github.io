# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
df = pd.read_csv("athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
### Only Medalists

# %%
df.dropna(subset= ['Medal'], inplace=True)

# %%
### Number of Medals = 39,783 Medals

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39783 entries, 3 to 271103
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      39783 non-null  int64
#  1   Name    39783 non-null  object
#  2   Sex     39783 non-null  object
#  3   Age     39051 non-null  float64
#  4   Height  31072 non-null  float64
#  5   Weight  30456 non-null  float64
#  6   Team    39783 non-null  object
#  7   NOC     39783 non-null  object
#  8   Games   39783 non-null  object
#  9   Year    39783 non-null  int64
#  10  Season  39783 non-null  object
#  11  City    39783 non-null  object
#  12  Sport   39783 non-null  object
#  13  Event   39783 non-null  object
#  14  Medal   39783 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 4.9+ MB

# %%
df.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 2  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 3  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#    NOC        Games  Year  Season       City       Sport  \
# 0  DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Event   Medal
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
Summer_df = df.loc[df["Season"] == "Summer", :]

# %%
Summer_df.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight            Team  NOC  \
# 0   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 1  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
# 2  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
# 4  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland  FIN
# 5  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland  FIN
#
#          Games  Year  Season       City       Sport  \
# 0  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 1  1920 Summer  1920  Summer  Antwerpen    Swimming
# 2  1920 Summer  1920  Summer  Antwerpen    Swimming
# 4  1948 Summer  1948  Summer     London  Gymnastics
# 5  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Event   Medal
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
Summer_df.describe()
# Out:
#                   ID           Age        Height        Weight          Year
# count   34088.000000  33367.000000  26098.000000  25598.000000  34088.000000
# mean    69317.155363     25.901579    177.938156     73.953388   1971.878667
# std     38927.611363      6.074975     11.216148     15.356776     34.745000
# min         4.000000     10.000000    136.000000     28.000000   1896.000000
# 25%     36065.000000     22.000000    170.000000     63.000000   1948.000000
# 50%     69191.000000     25.000000    178.000000     73.000000   1980.000000
# 75%    103371.250000     29.000000    185.000000     83.000000   2000.000000
# max    135563.000000     73.000000    223.000000    182.000000   2016.000000

# %%
Summer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34088 entries, 0 to 39782
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      34088 non-null  int64
#  1   Name    34088 non-null  object
#  2   Sex     34088 non-null  object
#  3   Age     33367 non-null  float64
#  4   Height  26098 non-null  float64
#  5   Weight  25598 non-null  float64
#  6   Team    34088 non-null  object
#  7   NOC     34088 non-null  object
#  8   Games   34088 non-null  object
#  9   Year    34088 non-null  int64
#  10  Season  34088 non-null  object
#  11  City    34088 non-null  object
#  12  Sport   34088 non-null  object
#  13  Event   34088 non-null  object
#  14  Medal   34088 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 4.2+ MB

# %%
### Gold Medals Won

gold_df = df.loc[df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

gold_df.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight            Team  \
# 0   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 6  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 7  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 9  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#          Games         City          Sport                             Event  \
# 0  1900 Summer        Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 5  1948 Summer       London     Gymnastics  Gymnastics Men's Team All-Around
# 6  1948 Summer       London     Gymnastics      Gymnastics Men's Horse Vault
# 7  1948 Summer       London     Gymnastics  Gymnastics Men's Pommelled Horse
# 9  1992 Winter  Albertville  Alpine Skiing       Alpine Skiing Men's Super G
#
#   Medal
# 0  Gold
# 5  Gold
# 6  Gold
# 7  Gold
# 9  Gold

# %%
gold_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13372 entries, 0 to 39777
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      13372 non-null  int64
#  1   Name    13372 non-null  object
#  2   Sex     13372 non-null  object
#  3   Age     13224 non-null  float64
#  4   Height  10539 non-null  float64
#  5   Weight  10254 non-null  float64
#  6   Team    13372 non-null  object
#  7   Games   13372 non-null  object
#  8   City    13372 non-null  object
#  9   Sport   13372 non-null  object
#  10  Event   13372 non-null  object
#  11  Medal   13372 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
### Silver Medals Won

silver_df = df.loc[df["Medal"] == "Silver", [
   "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]
silver_df.head()
# Out:
#     ID                Name Sex   Age  Height  Weight         Team  \
# 11  20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 13  20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 18  25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway
# 20  30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands
# 22  38        Karl Jan Aas   M  20.0     NaN     NaN       Norway
#
#           Games         City          Sport  \
# 11  1994 Winter  Lillehammer  Alpine Skiing
# 13  1994 Winter  Lillehammer  Alpine Skiing
# 18  1920 Summer    Antwerpen     Gymnastics
# 20  1996 Summer      Atlanta         Rowing
# 22  1920 Summer    Antwerpen     Gymnastics
#
#                                             Event   Medal
# 11                   Alpine Skiing Men's Downhill  Silver
# 13                   Alpine Skiing Men's Combined  Silver
# 18  Gymnastics Men's Team All-Around, Free System  Silver
# 20         Rowing Men's Lightweight Double Sculls  Silver
# ...

# %%
silver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13116 entries, 11 to 39782
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      13116 non-null  int64
#  1   Name    13116 non-null  object
#  2   Sex     13116 non-null  object
#  3   Age     12821 non-null  float64
#  4   Height  10167 non-null  float64
#  5   Weight  9975 non-null   float64
#  6   Team    13116 non-null  object
#  7   Games   13116 non-null  object
#  8   City    13116 non-null  object
#  9   Sport   13116 non-null  object
#  10  Event   13116 non-null  object
#  11  Medal   13116 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
### Bronze Medals Won

bronze_df = df.loc[df["Medal"] == "Bronze", [
   "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]
bronze_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight     Team  \
# 1  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 2  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 3  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 8  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
#
#          Games       City       Sport                                   Event  \
# 1  1920 Summer  Antwerpen    Swimming  Swimming Men's 200 metres Breaststroke
# 2  1920 Summer  Antwerpen    Swimming  Swimming Men's 400 metres Breaststroke
# 3  2014 Winter      Sochi  Ice Hockey             Ice Hockey Men's Ice Hockey
# 4  1948 Summer     London  Gymnastics  Gymnastics Men's Individual All-Around
# 8  1952 Summer   Helsinki  Gymnastics        Gymnastics Men's Team All-Around
#
#     Medal
# 1  Bronze
# 2  Bronze
# 3  Bronze
# 4  Bronze
# 8  Bronze

# %%
bronze_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13295 entries, 1 to 39781
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      13295 non-null  int64
#  1   Name    13295 non-null  object
#  2   Sex     13295 non-null  object
#  3   Age     13006 non-null  float64
#  4   Height  10366 non-null  float64
#  5   Weight  10227 non-null  float64
#  6   Team    13295 non-null  object
#  7   Games   13295 non-null  object
#  8   City    13295 non-null  object
#  9   Sport   13295 non-null  object
#  10  Event   13295 non-null  object
#  11  Medal   13295 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
### Medals Won Per Team

Team_Medals = df.groupby('Team')['Medal'].nunique()
Team_Medals
# Out:
# Team
# A North American Team           1
# Afghanistan                     1
# Algeria                         3
# Ali-Baba II                     1
# Amateur Athletic Association    1
#                                ..
# Winnipeg Shamrocks-1            1
# Yugoslavia                      3
# Zambia                          2
# Zimbabwe                        3
# Zut                             1
# Name: Medal, Length: 498, dtype: int64

# %%
### Number of Athletes Per Team

Team_IDs = df.groupby('Team')['ID'].nunique()
Team_IDs
# Out:
# Team
# A North American Team             4
# Afghanistan                       1
# Algeria                          14
# Ali-Baba II                       5
# Amateur Athletic Association      5
#                                ...
# Winnipeg Shamrocks-1             12
# Yugoslavia                      317
# Zambia                            2
# Zimbabwe                         16
# Zut                               3
# Name: ID, Length: 498, dtype: int64

# %%
### Number of Medals per Place

df['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
### Medals Won Per Country

Total_Medals = df['Team'].value_counts()
Total_Medals.head(25)
# Out:
# United States     5219
# Soviet Union      2451
# Germany           1984
# Great Britain     1673
# France            1550
# Italy             1527
# Sweden            1434
# Australia         1306
# Canada            1243
# Hungary           1127
# Russia            1110
# Netherlands        988
# East Germany       941
# Japan              911
# Norway             910
# China              901
# Finland            876
# Romania            651
# South Korea        592
# Switzerland        588
# Poland             563
# West Germany       558
# Denmark            553
# Czechoslovakia     486
# Spain              483
# Name: Team, dtype: int64

# %%
Total_Medals_df = pd.DataFrame(Total_Medals)
Total_Medals_df.head()
# Out:
#                Team
# United States  5219
# Soviet Union   2451
# Germany        1984
# Great Britain  1673
# France         1550

# %%
Total_Medals_df = Total_Medals_df.rename(
    columns={"Team": "Medals"})
Total_Medals_df.head()
# Out:
#                Medals
# United States    5219
# Soviet Union     2451
# Germany          1984
# Great Britain    1673
# France           1550

# %%
### Average Age, Height, and Weight of All Medal Winning Athletes (some duplicate stats due to multiple medal athletes)

df.describe()
# Out:
#                   ID           Age        Height        Weight          Year
# count   39783.000000  39051.000000  31072.000000  30456.000000  39783.000000
# mean    69407.051806     25.925175    177.554197     73.770680   1973.943845
# std     38849.980737      5.914026     10.893723     15.016025     33.822857
# min         4.000000     10.000000    136.000000     28.000000   1896.000000
# 25%     36494.000000     22.000000    170.000000     63.000000   1952.000000
# 50%     68990.000000     25.000000    178.000000     73.000000   1984.000000
# 75%    103461.500000     29.000000    185.000000     83.000000   2002.000000
# max    135563.000000     73.000000    223.000000    182.000000   2016.000000

# %%
df_M = df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

df_M.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 2  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 3  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#          Games       City       Sport                                   Event  \
# 0  1900 Summer      Paris  Tug-Of-War             Tug-Of-War Men's Tug-Of-War
# 1  1920 Summer  Antwerpen    Swimming  Swimming Men's 200 metres Breaststroke
# 2  1920 Summer  Antwerpen    Swimming  Swimming Men's 400 metres Breaststroke
# 3  2014 Winter      Sochi  Ice Hockey             Ice Hockey Men's Ice Hockey
# 4  1948 Summer     London  Gymnastics  Gymnastics Men's Individual All-Around
#
#     Medal
# 0    Gold
# 1  Bronze
# 2  Bronze
# ...

# %%
### Average Male Medalist Stats
### Age = 26.50 Height = 181.16cm Weight = 79.20kg

df_M.describe()
# Out:
#                   ID           Age        Height        Weight
# count   28530.000000  27815.000000  20594.000000  20104.000000
# mean    68664.838205     26.497178    181.156113     79.203782
# std     38733.571518      6.061054      9.974685     14.000333
# min         4.000000     10.000000    140.000000     37.000000
# 25%     35794.000000     22.000000    175.000000     70.000000
# 50%     68275.000000     25.000000    181.000000     78.000000
# 75%    102581.250000     29.000000    188.000000     87.000000
# max    135554.000000     73.000000    223.000000    182.000000

# %%
df_F = df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]


df_F.head()
# Out:
#     ID                                     Name Sex   Age  Height  Weight  \
# 17  21                Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 19  29                     Willemien Aardenburg   F  22.0     NaN     NaN
# 21  37                       Ann Kristin Aarnes   F  23.0   182.0    64.0
# 29  65                        Patimat Abakarova   F  21.0   165.0    49.0
# 30  67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
#
#            Team        Games            City      Sport  \
# 17       Norway  2008 Summer         Beijing   Handball
# 19  Netherlands  1988 Summer           Seoul     Hockey
# 21       Norway  1996 Summer         Atlanta   Football
# 29   Azerbaijan  2016 Summer  Rio de Janeiro  Taekwondo
# 30       Russia  2008 Summer         Beijing  Athletics
#
#                               Event   Medal
# 17        Handball Women's Handball    Gold
# 19            Hockey Women's Hockey  Bronze
# 21        Football Women's Football  Bronze
# ...

# %%
### Average Female Medalist Stats
### Age = 24.51 Height = 170.47cm Weight= 63.22kg

df_F.describe()
# Out:
#                   ID           Age        Height        Weight
# count   11253.000000  11236.000000  10478.000000  10352.000000
# mean    71288.803697     24.509167    170.474804     63.219378
# std     39082.168700      5.273018      8.986489     10.680266
# min        21.000000     11.000000    136.000000     28.000000
# 25%     37871.000000     21.000000    165.000000     57.000000
# 50%     70380.000000     24.000000    170.000000     63.000000
# 75%    106416.000000     28.000000    176.000000     70.000000
# max    135563.000000     69.000000    210.000000    167.000000

# %%
### Gold Medalists Male/Female

# %%
gold_df_M = gold_df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

gold_df_M.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight            Team  \
# 0   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 6  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 7  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 9  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#          Games         City          Sport                             Event  \
# 0  1900 Summer        Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 5  1948 Summer       London     Gymnastics  Gymnastics Men's Team All-Around
# 6  1948 Summer       London     Gymnastics      Gymnastics Men's Horse Vault
# 7  1948 Summer       London     Gymnastics  Gymnastics Men's Pommelled Horse
# 9  1992 Winter  Albertville  Alpine Skiing       Alpine Skiing Men's Super G
#
#   Medal
# 0  Gold
# 5  Gold
# 6  Gold
# 7  Gold
# 9  Gold

# %%
gold_df_M.describe()
# Out:
#                   ID          Age       Height       Weight
# count    9625.000000  9480.000000  7047.000000  6817.000000
# mean    68629.518753    26.504641   181.468568    79.588895
# std     38781.345128     6.032316    10.143372    14.126008
# min         4.000000    13.000000   140.000000    42.000000
# 25%     35741.000000    22.000000   175.000000    70.000000
# 50%     68371.000000    25.000000   182.000000    79.000000
# 75%    102615.000000    29.000000   188.000000    88.000000
# max    135545.000000    64.000000   223.000000   170.000000

# %%
gold_df_F = gold_df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

gold_df_F.head()
# Out:
#       ID                                  Name Sex   Age  Height  Weight  \
# 17    21             Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 57   150         Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 161  832                 Nicola Virginia Adams   F  29.0   164.0    51.0
# 162  832                 Nicola Virginia Adams   F  33.0   164.0    51.0
# 167  846  Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0   120.0
#
#               Team        Games            City      Sport  \
# 17          Norway  2008 Summer         Beijing   Handball
# 57   United States  1900 Summer           Paris       Golf
# 161  Great Britain  2012 Summer          London     Boxing
# 162  Great Britain  2016 Summer  Rio de Janeiro     Boxing
# 167    New Zealand  2008 Summer         Beijing  Athletics
#
#                           Event Medal
# 17    Handball Women's Handball  Gold
# 57      Golf Women's Individual  Gold
# 161    Boxing Women's Flyweight  Gold
# ...

# %%
gold_df_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    3747.000000  3744.000000  3492.000000  3437.000000
# mean    71230.252202    24.372596   170.693872    63.463486
# std     39603.057840     5.221598     9.134404    11.015370
# min        21.000000    13.000000   136.000000    28.000000
# 25%     36731.000000    21.000000   165.000000    57.000000
# 50%     70636.000000    24.000000   170.000000    63.000000
# 75%    107434.500000    27.000000   176.000000    70.000000
# max    135553.000000    63.000000   210.000000   136.000000

# %%
### Silver Medalists Male/Female

# %%
silver_df_M = silver_df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

silver_df_M.head()
# Out:
#     ID                Name Sex   Age  Height  Weight         Team  \
# 11  20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 13  20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway
# 18  25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway
# 20  30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands
# 22  38        Karl Jan Aas   M  20.0     NaN     NaN       Norway
#
#           Games         City          Sport  \
# 11  1994 Winter  Lillehammer  Alpine Skiing
# 13  1994 Winter  Lillehammer  Alpine Skiing
# 18  1920 Summer    Antwerpen     Gymnastics
# 20  1996 Summer      Atlanta         Rowing
# 22  1920 Summer    Antwerpen     Gymnastics
#
#                                             Event   Medal
# 11                   Alpine Skiing Men's Downhill  Silver
# 13                   Alpine Skiing Men's Combined  Silver
# 18  Gymnastics Men's Team All-Around, Free System  Silver
# 20         Rowing Men's Lightweight Double Sculls  Silver
# ...

# %%
silver_df_M.describe()
# Out:
#                   ID          Age       Height       Weight
# count    9381.000000  9092.000000  6692.000000  6536.000000
# mean    68615.316917    26.633194   181.072026    79.157895
# std     38768.955328     6.191528     9.911017    13.665014
# min        20.000000    13.000000   145.000000    47.000000
# 25%     35827.000000    23.000000   175.000000    70.000000
# 50%     68415.000000    26.000000   181.000000    78.000000
# 75%    102369.000000    29.000000   188.000000    87.000000
# max    135544.000000    73.000000   223.000000   154.000000

# %%
silver_df_F = silver_df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

silver_df_F.head()
# Out:
#      ID                                     Name Sex   Age  Height  Weight  \
# 30   67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 40   90                Tamila Rashidovna Abasova   F  21.0   163.0    60.0
# 58  153                    Monica Cecilia Abbott   F  23.0   191.0    88.0
# 59  165                      Nia Nicole Abdallah   F  20.0   175.0    56.0
# 76  394                               Irene Abel   F  19.0   160.0    48.0
#
#              Team        Games     City       Sport  \
# 30         Russia  2008 Summer  Beijing   Athletics
# 40         Russia  2004 Summer   Athina     Cycling
# 58  United States  2008 Summer  Beijing    Softball
# 59  United States  2004 Summer   Athina   Taekwondo
# 76   East Germany  1972 Summer   Munich  Gymnastics
#
#                                  Event   Medal
# 30     Athletics Women's Javelin Throw  Silver
# 40              Cycling Women's Sprint  Silver
# 58           Softball Women's Softball  Silver
# ...

# %%
silver_df_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    3735.000000  3729.000000  3475.000000  3439.000000
# mean    70841.764391    24.444891   170.498993    63.167345
# std     38859.395087     5.257146     8.933303    10.655152
# min        67.000000    11.000000   136.000000    30.000000
# 25%     38255.000000    21.000000   165.000000    57.000000
# 50%     69392.000000    24.000000   170.000000    63.000000
# 75%    105256.000000    27.000000   176.000000    69.000000
# max    135563.000000    55.000000   204.000000   167.000000

# %%
### Bronze Medalists Male/Female

# %%
bronze_df_M = bronze_df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

bronze_df_M.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight     Team  \
# 1  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 2  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 3  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 8  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
#
#          Games       City       Sport                                   Event  \
# 1  1920 Summer  Antwerpen    Swimming  Swimming Men's 200 metres Breaststroke
# 2  1920 Summer  Antwerpen    Swimming  Swimming Men's 400 metres Breaststroke
# 3  2014 Winter      Sochi  Ice Hockey             Ice Hockey Men's Ice Hockey
# 4  1948 Summer     London  Gymnastics  Gymnastics Men's Individual All-Around
# 8  1952 Summer   Helsinki  Gymnastics        Gymnastics Men's Team All-Around
#
#     Medal
# 1  Bronze
# 2  Bronze
# 3  Bronze
# 4  Bronze
# 8  Bronze

# %%
bronze_df_M.describe()
# Out:
#                   ID          Age       Height       Weight
# count    9524.000000  9243.000000  6855.000000  6751.000000
# mean    68749.309954    26.355729   180.916995    78.859329
# std     38654.239605     5.957346     9.854247    14.184808
# min        15.000000    10.000000   142.000000    37.000000
# 25%     35803.250000    22.000000   175.000000    70.000000
# 50%     67855.500000    25.000000   181.000000    78.000000
# 75%    102735.500000    29.000000   187.000000    87.000000
# max    135554.000000    72.000000   223.000000   182.000000

# %%
bronze_df_F = bronze_df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

bronze_df_F.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  \
# 19   29  Willemien Aardenburg   F  22.0     NaN     NaN  Netherlands
# 21   37    Ann Kristin Aarnes   F  23.0   182.0    64.0       Norway
# 29   65     Patimat Abakarova   F  21.0   165.0    49.0   Azerbaijan
# 61  259            Reema Abdo   F  21.0   173.0    59.0       Canada
# 77  395         Jennifer Abel   F  20.0   160.0    62.0       Canada
#
#           Games            City      Sport  \
# 19  1988 Summer           Seoul     Hockey
# 21  1996 Summer         Atlanta   Football
# 29  2016 Summer  Rio de Janeiro  Taekwondo
# 61  1984 Summer     Los Angeles   Swimming
# 77  2012 Summer          London     Diving
#
#                                            Event   Medal
# 19                         Hockey Women's Hockey  Bronze
# 21                     Football Women's Football  Bronze
# 29                   Taekwondo Women's Flyweight  Bronze
# ...

# %%
bronze_df_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    3771.000000  3763.000000  3511.000000  3476.000000
# mean    71789.754177    24.708743   170.232982    63.029488
# std     38784.609799     5.334748     8.886711    10.362310
# min        29.000000    12.000000   136.000000    28.000000
# 25%     39621.500000    21.000000   165.000000    57.000000
# 50%     71530.000000    24.000000   170.000000    63.000000
# 75%    106039.000000    28.000000   176.000000    69.000000
# max    135563.000000    69.000000   205.000000   141.000000

# %%
### All Medalists per Top 5 Winning Teams - USA, Soviet Union, Germany, Great Britain, France

# %%
### All USA Medalists

USA_df = Summer_df.loc[df["Team"] == "United States", :]
USA_df
# Out:
#            ID                                     Name Sex   Age  Height  \
# 37         84                     Stephen Anthony Abas   M  26.0   165.0
# 57        150            Margaret Ives Abbott (-Dunne)   F  23.0     NaN
# 58        153                    Monica Cecilia Abbott   F  23.0   191.0
# 59        165                      Nia Nicole Abdallah   F  20.0   175.0
# 68        351               Julius Shareef Abdur-Rahim   M  23.0   202.0
# ...       ...                                      ...  ..   ...     ...
# 39622  135045                            Rbert Zimonyi   M  46.0   170.0
# 39638  135103                Albert Conrad "Al" Zirkel   M  19.0     NaN
# 39655  135165  Kimberley Lyn "Kim" Zmeskal (-Burdette)   F  16.0   139.0
# 39662  135184            Jacqueline Jean "Jackie" Zoch   F  27.0   180.0
# 39684  135256                       Zachary "Zac" Zorn   M  21.0   193.0
#
#        Weight           Team  NOC        Games  Year  Season         City  \
# ...

# %%
USA_gold_medalists = USA_df.loc[df["Medal"] == "Gold", :]
USA_gold_medalists.head()
# Out:
#       ID                             Name Sex   Age  Height  Weight  \
# 57   150    Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 68   351       Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 85   423          Michael Brent Abernathy   M  22.0   182.0    84.0
# 89   454        Edgar Allen "Ed" Ablowich   M  19.0   182.0    68.0
# 136  699  Charles Edwin "Charley" Ackerly   M  22.0     NaN     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 57   United States  USA  1900 Summer  1900  Summer        Paris        Golf
# 68   United States  USA  2000 Summer  2000  Summer       Sydney  Basketball
# 85   United States  USA  2000 Summer  2000  Summer       Sydney    Baseball
# 89   United States  USA  1932 Summer  1932  Summer  Los Angeles   Athletics
# 136  United States  USA  1920 Summer  1920  Summer    Antwerpen   Wrestling
#
#                                         Event Medal
# ...

# %%
USA_gold_medalists['Medal'].value_counts()
# Out:
# Gold    2333
# Name: Medal, dtype: int64

# %%
USA_gold_medalists['Name'].value_counts().head(20)
# Out:
# Michael Fred Phelps, II                            23
# Raymond Clarence "Ray" Ewry                        10
# Mark Andrew Spitz                                   9
# Frederick Carlton "Carl" Lewis                      9
# Matthew Nicholas "Matt" Biondi                      8
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     8
# Donald Arthur "Don" Schollander                     7
# Allyson Michelle Felix                              6
# Ryan Steven Lochte                                  6
# Amy Deloris Van Dyken (-Rouen)                      6
# Peter Johann "Johnny" Weissmuller                   5
# Gary Wayne Hall, Jr.                                5
# Melissa Jeanette "Missy" Franklin                   5
# Stephen Edward "Steve" Clark                        5
# Dana Whitney Vollmer (-Grant)                       5
# Willis Augustus Lee, Jr.                            5
# Aaron Wells Peirsol                                 5
# ...

# %%
USA_df['Medal'].value_counts()
# Out:
# Gold      2333
# Silver    1241
# Bronze    1112
# Name: Medal, dtype: int64

# %%
USA_df['Name'].value_counts().head(20)
# Out:
# Michael Fred Phelps, II                            28
# Ryan Steven Lochte                                 12
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    12
# Dara Grace Torres (-Hoffman, -Minas)               12
# Natalie Anne Coughlin (-Hall)                      12
# Carl Townsend Osburn                               11
# Mark Andrew Spitz                                  11
# Matthew Nicholas "Matt" Biondi                     11
# Gary Wayne Hall, Jr.                               10
# Raymond Clarence "Ray" Ewry                        10
# Frederick Carlton "Carl" Lewis                     10
# Shirley Frances Babashoff                           9
# Allyson Michelle Felix                              9
# Martin Joseph Sheridan                              9
# Jason Edward Lezak                                  8
# Donald Arthur "Don" Schollander                     8
# Allison Rodgers Schmitt                             8
# ...

# %%
USA_df['Sport'].value_counts().head()
# Out:
# Athletics     1071
# Swimming      1066
# Basketball     341
# Rowing         333
# Shooting       193
# Name: Sport, dtype: int64

# %%
USA_medals = USA_df['Year'].value_counts()
USA_medals
# Out:
# 1984    352
# 2008    309
# 2004    259
# 2016    256
# 1996    255
# 2000    240
# 2012    238
# 1992    222
# 1988    207
# 1904    199
# 1920    194
# 1924    174
# 1972    171
# 1932    170
# 1968    166
# 1976    164
# 1964    159
# 1948    143
# 1952    122
# 1956    121
# 1960    120
# 1912    107
# 1936     96
# 1928     88
# 1908     65
# 1900     45
# 1906     24
# 1896     20
# Name: Year, dtype: int64

# %%
USA_gold_medals = USA_gold_medalists['Year'].value_counts()
USA_gold_medals
# Out:
# 1984    186
# 1996    157
# 2012    139
# 2016    137
# 2000    128
# 2008    121
# 2004    115
# 1920    111
# 1968     99
# 1964     95
# 1924     91
# 1988     87
# 1992     87
# 1948     80
# 1960     78
# 1952     73
# 1976     70
# 1972     69
# 1932     67
# 1904     65
# 1956     59
# 1936     51
# 1928     47
# 1912     46
# 1908     34
# 1900     18
# 1906     12
# 1896     11
# Name: Year, dtype: int64

# %%
USA_gold_medals_df = pd.DataFrame(USA_gold_medals)
USA_gold_medals_df.head()
# Out:
#       Year
# 1984   186
# 1996   157
# 2012   139
# 2016   137
# 2000   128

# %%
USA_gold_medals_df.plot.bar()

# %%
Years_USA_df = USA_df['Year'].value_counts()
Plot_USA_df = pd.DataFrame(Years_USA_df)

# %%
Plot_USA_df = Plot_USA_df.rename(
    columns={"Year": "Medals"})

# %%
Plot_USA_df.sort_index(inplace=True)
Plot_USA_df
# Out:
#       Medals
# 1896      20
# 1900      45
# 1904     199
# 1906      24
# 1908      65
# 1912     107
# 1920     194
# 1924     174
# 1928      88
# 1932     170
# 1936      96
# 1948     143
# 1952     122
# 1956     121
# 1960     120
# 1964     159
# 1968     166
# 1972     171
# 1976     164
# 1984     352
# 1988     207
# 1992     222
# 1996     255
# 2000     240
# 2004     259
# 2008     309
# 2012     238
# 2016     256

# %%
ax = Plot_USA_df.plot.bar(y='Medals', rot=0)

# %%
### All Soviet Union Medalists

Soviet_Union_df = df.loc[df["Team"] == "Soviet Union", :]
Soviet_Union_df.head()
# Out:
#       ID                              Name Sex   Age  Height  Weight  \
# 64   316  Zagalav Abdulbekovich Abdulbekov   M  26.0   160.0    62.0
# 95   460        Viktor Andreyevich Aboimov   M  22.0   190.0    78.0
# 96   460        Viktor Andreyevich Aboimov   M  22.0   190.0    78.0
# 110  547        Nelli Mikhaylovna Abramova   F  24.0   171.0    60.0
# 114  582       Saypulla Atavovich Absaidov   M  22.0   168.0    68.0
#
#              Team  NOC        Games  Year  Season    City       Sport  \
# 64   Soviet Union  URS  1972 Summer  1972  Summer  Munich   Wrestling
# 95   Soviet Union  URS  1972 Summer  1972  Summer  Munich    Swimming
# 96   Soviet Union  URS  1972 Summer  1972  Summer  Munich    Swimming
# 110  Soviet Union  URS  1964 Summer  1964  Summer   Tokyo  Volleyball
# 114  Soviet Union  URS  1980 Summer  1980  Summer  Moskva   Wrestling
#
#                                              Event   Medal
# 64        Wrestling Men's Featherweight, Freestyle    Gold
# ...

# %%
Soviet_Union_df['Medal'].value_counts()
# Out:
# Gold      1058
# Silver     716
# Bronze     677
# Name: Medal, dtype: int64

# %%
Soviet_Union_df['Name'].value_counts()
# Out:
# Larysa Semenivna Latynina (Diriy-)    18
# Nikolay Yefimovich Andrianov          15
# Borys Anfiyanovych Shakhlin           13
# Viktor Ivanovych Chukarin             11
# Aleksandr Nikolayevich Dityatin       10
#                                       ..
# Sergey Sergeyevich Salnikov            1
# Vladimir Sergeyevich Yumin             1
# Valery Yakovlevich Volkov              1
# Viktor Grigoryevich Shuvalov           1
# Natella Arkhipovna Krasnikova          1
# Name: Name, Length: 1638, dtype: int64

# %%
Soviet_Union_df['Sport'].value_counts().head()
# Out:
# Gymnastics    288
# Athletics     242
# Ice Hockey    168
# Rowing        155
# Fencing       146
# Name: Sport, dtype: int64

# %%
Soviet_Union_df['Year'].value_counts()
# Out:
# 1980    488
# 1988    352
# 1976    336
# 1972    255
# 1968    225
# 1964    219
# 1960    209
# 1956    206
# 1952    117
# 1984     44
# Name: Year, dtype: int64

# %%
### All Germany Medalists

Germany_df = df.loc[df["Team"] == "Germany", :]
Germany_df.head()
# Out:
#       ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 137  702      Ronny Ackermann   M  24.0   184.0    69.0  Germany  GER
# 138  702      Ronny Ackermann   M  24.0   184.0    69.0  Germany  GER
# 139  702      Ronny Ackermann   M  28.0   184.0    69.0  Germany  GER
# 152  775            Otto Adam   M  26.0     NaN     NaN  Germany  GER
# 170  849  Filip Kamil Adamski   M  29.0   189.0    87.0  Germany  GER
#
#            Games  Year  Season            City            Sport  \
# 137  2002 Winter  2002  Winter  Salt Lake City  Nordic Combined
# 138  2002 Winter  2002  Winter  Salt Lake City  Nordic Combined
# 139  2006 Winter  2006  Winter          Torino  Nordic Combined
# 152  1936 Summer  1936  Summer          Berlin          Fencing
# 170  2012 Summer  2012  Summer          London           Rowing
#
#                             Event   Medal
# 137    Nordic Combined Men's Team  Silver
# 138  Nordic Combined Men's Sprint  Silver
# ...

# %%
Germany_df['Medal'].value_counts()
# Out:
# Gold      679
# Bronze    678
# Silver    627
# Name: Medal, dtype: int64

# %%
Germany_df['Name'].value_counts()
# Out:
# Franziska van Almsick     10
# Ursula "Uschi" Disl        9
# Claudia Pechstein          9
# Isabelle Regina Werth      9
# Birgit Fischer-Schmidt     8
#                           ..
# Erwin Koppe                1
# Lutz Altepost              1
# Emil Schulz                1
# Otto Froitzheim            1
# Tobias Schellenberg        1
# Name: Name, Length: 1386, dtype: int64

# %%
Germany_df['Sport'].value_counts().head()
# Out:
# Rowing       204
# Hockey       182
# Canoeing     159
# Athletics    154
# Swimming     152
# Name: Sport, dtype: int64

# %%
Germany_df['Year'].value_counts()
# Out:
# 1992    224
# 1936    220
# 2016    157
# 2004    147
# 1996    122
# 1964    121
# 2000    116
# 2008     96
# 1960     93
# 2012     92
# 1928     77
# 1956     54
# 1932     53
# 2002     49
# 1952     45
# 2006     44
# 2010     42
# 1912     39
# 1998     34
# 2014     32
# 1896     31
# 1994     30
# 1906     30
# 1908     19
# 1904     15
# 1900      2
# Name: Year, dtype: int64

# %%
### All Great Britain Medalists

Great_Britain_df = df.loc[df["Team"] == "Great Britain", :]
Great_Britain_df.head()
# Out:
#       ID                     Name Sex   Age  Height  Weight           Team  \
# 102  509             Gary Abraham   M  21.0   175.0    64.0  Great Britain
# 104  519  Harold Maurice Abrahams   M  24.0   183.0    75.0  Great Britain
# 105  519  Harold Maurice Abrahams   M  24.0   183.0    75.0  Great Britain
# 159  830        Adrian Neil Adams   M  21.0   178.0    78.0  Great Britain
# 160  830        Adrian Neil Adams   M  25.0   178.0    78.0  Great Britain
#
#      NOC        Games  Year  Season         City      Sport  \
# 102  GBR  1980 Summer  1980  Summer       Moskva   Swimming
# 104  GBR  1924 Summer  1924  Summer        Paris  Athletics
# 105  GBR  1924 Summer  1924  Summer        Paris  Athletics
# 159  GBR  1980 Summer  1980  Summer       Moskva       Judo
# 160  GBR  1984 Summer  1984  Summer  Los Angeles       Judo
#
#                                           Event   Medal
# 102  Swimming Men's 4 x 100 metres Medley Relay  Bronze
# ...

# %%
Great_Britain_df['Medal'].value_counts()
# Out:
# Silver    582
# Bronze    572
# Gold      519
# Name: Medal, dtype: int64

# %%
Great_Britain_df['Name'].value_counts()
# Out:
# Henry Taylor                           8
# Bradley Marc Wiggins                   8
# Jason Francis Kenny                    7
# Christopher Andrew "Chris" Hoy         7
# Stephen Geoffrey "Steven" Redgrave     6
#                                       ..
# Edward Adams Spencer                   1
# Harold E. West                         1
# Helen Reeves                           1
# Yvonne Carol Grace Murray (-Mooney)    1
# Charles Edward James "Charlie" Gunn    1
# Name: Name, Length: 1271, dtype: int64

# %%
Great_Britain_df['Sport'].value_counts().head()
# Out:
# Athletics    334
# Rowing       217
# Cycling      169
# Swimming     127
# Hockey       118
# Name: Sport, dtype: int64

# %%
Great_Britain_df['Year'].value_counts()
# Out:
# 1908    167
# 2016    145
# 1912    128
# 2012    122
# 1920    101
# 1924     82
# 2008     81
# 1984     71
# 1948     61
# 1928     59
# 2004     55
# 1988     54
# 2000     52
# 1992     50
# 1980     48
# 1936     47
# 1956     37
# 1976     33
# 1932     33
# 1952     32
# 1906     31
# 1972     29
# 1960     28
# 1964     26
# 1996     26
# 1900     22
# 1968     19
# 2014     10
# 1896      7
# 2002      6
# 1998      4
# 1994      3
# 1904      2
# 2006      1
# 2010      1
# Name: Year, dtype: int64

# %%
### All France Medalists

France_df = df.loc[df["Team"] == "France", :]
France_df.head()
# Out:
#     ID            Name Sex   Age  Height  Weight    Team  NOC        Games  \
# 26  56      Ren Abadie   M  21.0     NaN     NaN  France  FRA  1956 Summer
# 32  73       Luc Abalo   M  23.0   182.0    86.0  France  FRA  2008 Summer
# 33  73       Luc Abalo   M  27.0   182.0    86.0  France  FRA  2012 Summer
# 34  73       Luc Abalo   M  31.0   182.0    86.0  France  FRA  2016 Summer
# 41  93  Jol Marc Abati   M  38.0   190.0    85.0  France  FRA  2008 Summer
#
#     Year  Season            City     Sport                          Event  \
# 26  1956  Summer       Melbourne   Cycling  Cycling Men's Road Race, Team
# 32  2008  Summer         Beijing  Handball        Handball Men's Handball
# 33  2012  Summer          London  Handball        Handball Men's Handball
# 34  2016  Summer  Rio de Janeiro  Handball        Handball Men's Handball
# 41  2008  Summer         Beijing  Handball        Handball Men's Handball
#
#      Medal
# 26    Gold
# 32    Gold
# 33    Gold
# 34  Silver
# ...

# %%
France_df['Medal'].value_counts()
# Out:
# Bronze    577
# Silver    518
# Gold      455
# Name: Medal, dtype: int64

# %%
France_df['Name'].value_counts()
# Out:
# Philippe Louis Eugne Cattiau     8
# Roger Franois Ducret             8
# Lon Ernest Moreaux               7
# Lucien Alphonse Paul Gaudin      6
# Philippe Claude Riboud           6
#                                 ..
# Pascal Jean Michel Robert Mah    1
# Enzo-Boris Lefort                1
# mile Allais                      1
# Roger Gautier                    1
# Cdric Berrest                    1
# Name: Name, Length: 1108, dtype: int64

# %%
France_df['Sport'].value_counts().head()
# Out:
# Fencing      310
# Cycling      151
# Athletics    110
# Rowing        89
# Handball      77
# Name: Sport, dtype: int64

# %%
France_df['Year'].value_counts()
# Out:
# 1920    134
# 1924    109
# 2016     96
# 2012     78
# 1948     77
# 2008     77
# 1900     75
# 1984     70
# 1992     65
# 2000     64
# 2004     53
# 1996     49
# 1928     46
# 1906     45
# 1936     45
# 1932     42
# 1952     41
# 1964     38
# 1968     36
# 1908     36
# 1956     33
# 1988     31
# 1980     30
# 1972     25
# 1912     23
# 1976     21
# 2014     18
# 1960     15
# 2006     15
# 2010     14
# 1998     13
# 2002     13
# 1994     11
# 1896     11
# 1904      1
# Name: Year, dtype: int64

# %%
Years_France_df = France_df['Year'].value_counts()

# %%
Plot_France_df = pd.DataFrame(Years_France_df)
Plot_France_df.head()
# Out:
#       Year
# 1920   134
# 1924   109
# 2016    96
# 2012    78
# 1948    77

# %%
Plot_France_df = Plot_France_df.rename(
    columns={"Year": "Medals"})
Plot_France_df.head()
# Out:
#       Medals
# 1920     134
# 1924     109
# 2016      96
# 2012      78
# 1948      77

# %%
Plot_France_df.sort_index(inplace=True)
Plot_France_df.head()
# Out:
#       Medals
# 1896      11
# 1900      75
# 1904       1
# 1906      45
# 1908      36

# %%
ax = Plot_France_df.plot.bar(y='Medals', rot=0)

# %%
### 
Years_France_df = France_df['Year'].value_counts()
Plot_France_df = pd.DataFrame(Years_France_df)
Plot_France_df.head()

Plot_France_df = Plot_France_df.rename(
    columns={"Year": "Medals"})
Plot_France_df.head()

Plot_France_df.sort_index(inplace=True)
Plot_France_df.head()

ax = Plot_France_df.plot.bar(y='Medals', rot=0)

# %%
ax = USA_Bronze_F_df.head(10).plot.bar(y='Sport', title="USA Women's Bronze Medals - Sport", rot=0, figsize=(12,6), color='#b08d57')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-cff614738753> in <module>
# ----> 1 ax = USA_Bronze_F_df.head(10).plot.bar(y='Sport', title="USA Women's Bronze Medals - Sport", rot=0, figsize=(12,6), color='#b08d57')
#
# NameError: name 'USA_Bronze_F_df' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
Team_IDs2 = Summer_df.groupby('Team')['ID'].value_counts()
Team_IDs2.head(25)
