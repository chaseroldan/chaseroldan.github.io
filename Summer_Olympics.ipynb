# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib

# %%
# Read CSV
df = pd.read_csv("athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# Drop all non medalists
df.dropna(subset= ['Medal'], inplace=True)

# %%
df.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# 38  Swimming Men's 400 metres Breaststroke  Bronze
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39783 entries, 3 to 271103
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      39783 non-null  int64
#  1   Name    39783 non-null  object
#  2   Sex     39783 non-null  object
#  3   Age     39051 non-null  float64
#  4   Height  31072 non-null  float64
#  5   Weight  30456 non-null  float64
#  6   Team    39783 non-null  object
#  7   NOC     39783 non-null  object
#  8   Games   39783 non-null  object
#  9   Year    39783 non-null  int64
#  10  Season  39783 non-null  object
#  11  City    39783 non-null  object
#  12  Sport   39783 non-null  object
#  13  Event   39783 non-null  object
#  14  Medal   39783 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 4.9+ MB

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 2  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 3  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#    NOC        Games  Year  Season       City       Sport  \
# 0  DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Event   Medal
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# 3             Ice Hockey Men's Ice Hockey  Bronze
# 4  Gymnastics Men's Individual All-Around  Bronze

# %%
# Select only summer olympics
Summer_df = df.loc[df["Season"] == "Summer", :]
Summer_df.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight            Team  NOC  \
# 0   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 1  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
# 2  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
# 4  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland  FIN
# 5  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland  FIN
#
#          Games  Year  Season       City       Sport  \
# 0  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 1  1920 Summer  1920  Summer  Antwerpen    Swimming
# 2  1920 Summer  1920  Summer  Antwerpen    Swimming
# 4  1948 Summer  1948  Summer     London  Gymnastics
# 5  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Event   Medal
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# 4  Gymnastics Men's Individual All-Around  Bronze
# 5        Gymnastics Men's Team All-Around    Gold

# %%
Summer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34088 entries, 0 to 39782
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      34088 non-null  int64
#  1   Name    34088 non-null  object
#  2   Sex     34088 non-null  object
#  3   Age     33367 non-null  float64
#  4   Height  26098 non-null  float64
#  5   Weight  25598 non-null  float64
#  6   Team    34088 non-null  object
#  7   NOC     34088 non-null  object
#  8   Games   34088 non-null  object
#  9   Year    34088 non-null  int64
#  10  Season  34088 non-null  object
#  11  City    34088 non-null  object
#  12  Sport   34088 non-null  object
#  13  Event   34088 non-null  object
#  14  Medal   34088 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 4.2+ MB

# %%
Summer_df.describe()
# Out:
#                   ID           Age        Height        Weight          Year
# count   34088.000000  33367.000000  26098.000000  25598.000000  34088.000000
# mean    69317.155363     25.901579    177.938156     73.953388   1971.878667
# std     38927.611363      6.074975     11.216148     15.356776     34.745000
# min         4.000000     10.000000    136.000000     28.000000   1896.000000
# 25%     36065.000000     22.000000    170.000000     63.000000   1948.000000
# 50%     69191.000000     25.000000    178.000000     73.000000   1980.000000
# 75%    103371.250000     29.000000    185.000000     83.000000   2000.000000
# max    135563.000000     73.000000    223.000000    182.000000   2016.000000

# %%
# Gold medals won - all teams
Gold_df = Summer_df.loc[Summer_df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_df.head()
# Out:
#     ID                       Name Sex   Age  Height  Weight            Team  \
# 0    4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5   17    Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 6   17    Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 7   17    Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 17  21  Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN          Norway
#
#           Games     City       Sport                             Event Medal
# 0   1900 Summer    Paris  Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 5   1948 Summer   London  Gymnastics  Gymnastics Men's Team All-Around  Gold
# 6   1948 Summer   London  Gymnastics      Gymnastics Men's Horse Vault  Gold
# 7   1948 Summer   London  Gymnastics  Gymnastics Men's Pommelled Horse  Gold
# 17  2008 Summer  Beijing    Handball         Handball Women's Handball  Gold

# %%
Gold_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11459 entries, 0 to 39777
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      11459 non-null  int64
#  1   Name    11459 non-null  object
#  2   Sex     11459 non-null  object
#  3   Age     11320 non-null  float64
#  4   Height  8862 non-null   float64
#  5   Weight  8623 non-null   float64
#  6   Team    11459 non-null  object
#  7   Games   11459 non-null  object
#  8   City    11459 non-null  object
#  9   Sport   11459 non-null  object
#  10  Event   11459 non-null  object
#  11  Medal   11459 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
Gold_df.describe()
# Out:
#                   ID           Age       Height       Weight
# count   11459.000000  11320.000000  8862.000000  8623.000000
# mean    69169.897286     25.857951   178.292823    74.352372
# std     38983.921829      6.044506    11.355919    15.519424
# min         4.000000     13.000000   136.000000    28.000000
# 25%     35702.000000     22.000000   170.000000    63.000000
# 50%     69209.000000     25.000000   178.000000    73.000000
# 75%    103275.000000     29.000000   186.000000    84.000000
# max    135553.000000     64.000000   223.000000   170.000000

# %%
# Silver medals won - all teams
Silver_df = Summer_df.loc[Summer_df["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_df.head()
# Out:
#     ID                                     Name Sex   Age  Height  Weight  \
# 18  25                         Alf Lied Aanning   M  24.0     NaN     NaN
# 20  30                         Pepijn Aardewijn   M  26.0   189.0    72.0
# 22  38                             Karl Jan Aas   M  20.0     NaN     NaN
# 30  67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 34  73                                Luc Abalo   M  31.0   182.0    86.0
#
#            Team        Games            City       Sport  \
# 18       Norway  1920 Summer       Antwerpen  Gymnastics
# 20  Netherlands  1996 Summer         Atlanta      Rowing
# 22       Norway  1920 Summer       Antwerpen  Gymnastics
# 30       Russia  2008 Summer         Beijing   Athletics
# 34       France  2016 Summer  Rio de Janeiro    Handball
#
#                                             Event   Medal
# 18  Gymnastics Men's Team All-Around, Free System  Silver
# 20         Rowing Men's Lightweight Double Sculls  Silver
# 22  Gymnastics Men's Team All-Around, Free System  Silver
# 30                Athletics Women's Javelin Throw  Silver
# 34                        Handball Men's Handball  Silver

# %%
Silver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11220 entries, 18 to 39782
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      11220 non-null  int64
#  1   Name    11220 non-null  object
#  2   Sex     11220 non-null  object
#  3   Age     10925 non-null  float64
#  4   Height  8490 non-null   float64
#  5   Weight  8333 non-null   float64
#  6   Team    11220 non-null  object
#  7   Games   11220 non-null  object
#  8   City    11220 non-null  object
#  9   Sport   11220 non-null  object
#  10  Event   11220 non-null  object
#  11  Medal   11220 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
Silver_df.describe()
# Out:
#                   ID           Age       Height       Weight
# count   11220.000000  10925.000000  8490.000000  8333.000000
# mean    69188.038235     25.987551   177.834511    73.826353
# std     38945.470193      6.192730    11.172179    15.179126
# min        25.000000     11.000000   136.000000    30.000000
# 25%     36483.000000     22.000000   170.000000    63.000000
# 50%     68949.500000     25.000000   178.000000    73.000000
# 75%    103119.500000     29.000000   185.000000    83.000000
# max    135563.000000     73.000000   223.000000   167.000000

# %%
# Bronze medals won - all teams
Bronze_df = Summer_df.loc[Summer_df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_df.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight         Team  \
# 1   15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN      Finland
# 2   15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN      Finland
# 4   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0      Finland
# 8   17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0      Finland
# 19  29     Willemien Aardenburg   F  22.0     NaN     NaN  Netherlands
#
#           Games       City       Sport  \
# 1   1920 Summer  Antwerpen    Swimming
# 2   1920 Summer  Antwerpen    Swimming
# 4   1948 Summer     London  Gymnastics
# 8   1952 Summer   Helsinki  Gymnastics
# 19  1988 Summer      Seoul      Hockey
#
#                                      Event   Medal
# 1   Swimming Men's 200 metres Breaststroke  Bronze
# 2   Swimming Men's 400 metres Breaststroke  Bronze
# 4   Gymnastics Men's Individual All-Around  Bronze
# 8         Gymnastics Men's Team All-Around  Bronze
# 19                   Hockey Women's Hockey  Bronze

# %%
Bronze_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11409 entries, 1 to 39781
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      11409 non-null  int64
#  1   Name    11409 non-null  object
#  2   Sex     11409 non-null  object
#  3   Age     11122 non-null  float64
#  4   Height  8746 non-null   float64
#  5   Weight  8642 non-null   float64
#  6   Team    11409 non-null  object
#  7   Games   11409 non-null  object
#  8   City    11409 non-null  object
#  9   Sport   11409 non-null  object
#  10  Event   11409 non-null  object
#  11  Medal   11409 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
Bronze_df.describe()
# Out:
#                   ID           Age       Height       Weight
# count   11409.000000  11122.000000  8746.000000  8642.000000
# mean    69592.036988     25.861536   177.679396    73.677775
# std     38855.330426      5.988155    11.107866    15.357555
# min        15.000000     10.000000   136.000000    28.000000
# 25%     36335.000000     22.000000   170.000000    63.000000
# 50%     69288.000000     25.000000   178.000000    72.000000
# 75%    103685.000000     29.000000   185.000000    82.000000
# max    135563.000000     72.000000   223.000000   182.000000

# %%
# Amount of medals per medal type
Summer_df['Medal'].value_counts()
# Out:
# Gold      11459
# Bronze    11409
# Silver    11220
# Name: Medal, dtype: int64

# %%
# Medals won per team
Team_Medals = Summer_df.groupby('Team')['Medal'].nunique()
Team_Medals
# Out:
# Team
# A North American Team           1
# Afghanistan                     1
# Algeria                         3
# Ali-Baba II                     1
# Amateur Athletic Association    1
#                                ..
# Winnipeg Shamrocks-1            1
# Yugoslavia                      3
# Zambia                          2
# Zimbabwe                        3
# Zut                             1
# Name: Medal, Length: 480, dtype: int64

# %%
# Athletes per team
Team_IDs = Summer_df.groupby('Team')['ID'].nunique()
Team_IDs
# Out:
# Team
# A North American Team             4
# Afghanistan                       1
# Algeria                          14
# Ali-Baba II                       5
# Amateur Athletic Association      5
#                                ...
# Winnipeg Shamrocks-1             12
# Yugoslavia                      311
# Zambia                            2
# Zimbabwe                         16
# Zut                               3
# Name: ID, Length: 480, dtype: int64

# %%
# Most team medals won
Most_Team_Medals = Summer_df['Team'].value_counts()
Most_Team_Medals.head(25)
# Out:
# United States    4686
# Soviet Union     2061
# Germany          1687
# Great Britain    1598
# France           1408
# Italy            1384
# Australia        1290
# Hungary          1123
# Sweden           1006
# Russia            894
# Netherlands       866
# Japan             848
# East Germany      841
# China             831
# Canada            668
# Romania           651
# Denmark           548
# Poland            536
# South Korea       506
# West Germany      502
# Spain             481
# Norway            467
# Finland           450
# Brazil            449
# Cuba              407
# Name: Team, dtype: int64

# %%
Most_Team_Medals = pd.DataFrame(Most_Team_Medals)
Most_Team_Medals.head(25)
# Out:
#                Team
# United States  4686
# Soviet Union   2061
# Germany        1687
# Great Britain  1598
# France         1408
# Italy          1384
# Australia      1290
# Hungary        1123
# Sweden         1006
# Russia          894
# Netherlands     866
# Japan           848
# East Germany    841
# China           831
# Canada          668
# Romania         651
# Denmark         548
# Poland          536
# South Korea     506
# West Germany    502
# Spain           481
# Norway          467
# Finland         450
# Brazil          449
# Cuba            407

# %%
# All male medalists for all teams
df_M = Summer_df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

df_M.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight            Team  \
# 0   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 2  15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 4  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 5  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#          Games       City       Sport                                   Event  \
# 0  1900 Summer      Paris  Tug-Of-War             Tug-Of-War Men's Tug-Of-War
# 1  1920 Summer  Antwerpen    Swimming  Swimming Men's 200 metres Breaststroke
# 2  1920 Summer  Antwerpen    Swimming  Swimming Men's 400 metres Breaststroke
# 4  1948 Summer     London  Gymnastics  Gymnastics Men's Individual All-Around
# 5  1948 Summer     London  Gymnastics        Gymnastics Men's Team All-Around
#
#     Medal
# 0    Gold
# 1  Bronze
# 2  Bronze
# 4  Bronze
# 5    Gold

# %%
df_M.describe()
# Out:
#                   ID           Age        Height        Weight
# count   24646.000000  23942.000000  17341.000000  16931.000000
# mean    68532.766047     26.500961    181.388617     79.264918
# std     38857.803325      6.238221     10.492965     14.500375
# min         4.000000     10.000000    140.000000     37.000000
# 25%     35261.750000     22.000000    175.000000     70.000000
# 50%     68434.500000     25.000000    182.000000     78.000000
# 75%    102563.000000     29.000000    188.000000     88.000000
# max    135554.000000     73.000000    223.000000    182.000000

# %%
# All male gold medalists for all teams
Gold_M = df_M.loc[df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_M.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 0    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 6   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 7   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 25  42      Thomas Valentin Aas   M  25.0     NaN     NaN          Taifun
#
#           Games       City       Sport                             Event Medal
# 0   1900 Summer      Paris  Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 5   1948 Summer     London  Gymnastics  Gymnastics Men's Team All-Around  Gold
# 6   1948 Summer     London  Gymnastics      Gymnastics Men's Horse Vault  Gold
# 7   1948 Summer     London  Gymnastics  Gymnastics Men's Pommelled Horse  Gold
# 25  1912 Summer  Stockholm     Sailing            Sailing Mixed 8 metres  Gold

# %%
Gold_M.describe()
# Out:
#                   ID          Age       Height       Weight
# count    8319.000000  8183.000000  5947.000000  5748.000000
# mean    68304.027648    26.488940   181.680343    79.632568
# std     38770.044452     6.195806    10.649788    14.567872
# min         4.000000    13.000000   140.000000    42.000000
# 25%     35373.500000    22.000000   175.000000    70.000000
# 50%     68241.000000    25.000000   182.000000    78.000000
# 75%    102348.000000    29.000000   189.000000    88.000000
# max    135545.000000    64.000000   223.000000   170.000000

# %%
# USA male gold medalists
USA_Gold_M = Gold_M.loc[df["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

USA_Gold_M.head()
# Out:
#       ID                             Name Sex   Age  Height  Weight  \
# 68   351       Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 85   423          Michael Brent Abernathy   M  22.0   182.0    84.0
# 89   454        Edgar Allen "Ed" Ablowich   M  19.0   182.0    68.0
# 136  699  Charles Edwin "Charley" Ackerly   M  22.0     NaN     NaN
# 149  762       Gordon Belgum "Gordy" Adam   M  21.0     NaN     NaN
#
#               Team        Games         City       Sport  \
# 68   United States  2000 Summer       Sydney  Basketball
# 85   United States  2000 Summer       Sydney    Baseball
# 89   United States  1932 Summer  Los Angeles   Athletics
# 136  United States  1920 Summer    Antwerpen   Wrestling
# 149  United States  1936 Summer       Berlin      Rowing
#
#                                         Event Medal
# 68                Basketball Men's Basketball  Gold
# 85                    Baseball Men's Baseball  Gold
# 89       Athletics Men's 4 x 400 metres Relay  Gold
# 136  Wrestling Men's Featherweight, Freestyle  Gold
# 149                 Rowing Men's Coxed Eights  Gold

# %%
USA_Gold_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1560 entries, 68 to 39684
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1560 non-null   int64
#  1   Name    1560 non-null   object
#  2   Sex     1560 non-null   object
#  3   Age     1558 non-null   float64
#  4   Height  1330 non-null   float64
#  5   Weight  1244 non-null   float64
#  6   Team    1560 non-null   object
#  7   Games   1560 non-null   object
#  8   City    1560 non-null   object
#  9   Sport   1560 non-null   object
#  10  Event   1560 non-null   object
#  11  Medal   1560 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 158.4+ KB

# %%
USA_Gold_M['Name'].value_counts().head(10)
# Out:
# Michael Fred Phelps, II              23
# Raymond Clarence "Ray" Ewry          10
# Mark Andrew Spitz                     9
# Frederick Carlton "Carl" Lewis        9
# Matthew Nicholas "Matt" Biondi        8
# Donald Arthur "Don" Schollander       7
# Ryan Steven Lochte                    6
# Alfred Page "Al" Lane                 5
# Peter Johann "Johnny" Weissmuller     5
# Gary Wayne Hall, Jr.                  5
# Name: Name, dtype: int64

# %%
USA_Gold_M_Name = USA_Gold_M['Name'].value_counts()
USA_Gold_M_Name = pd.DataFrame(USA_Gold_M_Name)
USA_Gold_M_Name.head(10)
# Out:
#                                    Name
# Michael Fred Phelps, II              23
# Raymond Clarence "Ray" Ewry          10
# Mark Andrew Spitz                     9
# Frederick Carlton "Carl" Lewis        9
# Matthew Nicholas "Matt" Biondi        8
# Donald Arthur "Don" Schollander       7
# Ryan Steven Lochte                    6
# Alfred Page "Al" Lane                 5
# Peter Johann "Johnny" Weissmuller     5
# Gary Wayne Hall, Jr.                  5

# %%
# Create bar chart for top USA male gold medalists
USA_Gold_M_Name_Chart = USA_Gold_M_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=0, color='gold')
USA_Gold_M_Name_Chart.set_ylabel("Medals Won")
USA_Gold_M_Name_Chart.set_title("USA Men's Gold Medals - Athlete Name")
plt.savefig('images/USA_Gold_M_Name.png')
plt.show()
plt.tight_layout()

# %%
USA_Gold_M['Sport'].value_counts()
# Out:
# Athletics           409
# Swimming            381
# Basketball          186
# Rowing              124
# Shooting            109
# Wrestling            51
# Boxing               48
# Volleyball           36
# Rugby                35
# Diving               28
# Gymnastics           27
# Baseball             24
# Equestrianism        22
# Sailing              21
# Weightlifting        15
# Cycling              12
# Archery              10
# Canoeing              6
# Tennis                5
# Art Competitions      4
# Taekwondo             2
# Fencing               2
# Roque                 1
# Golf                  1
# Jeu De Paume          1
# Name: Sport, dtype: int64

# %%
USA_Gold_M_Sports = USA_Gold_M['Sport'].value_counts()

# %%
USA_Gold_M_df = pd.DataFrame(USA_Gold_M_Sports)
USA_Gold_M_df.head()
# Out:
#             Sport
# Athletics     409
# Swimming      381
# Basketball    186
# Rowing        124
# Shooting      109

# %%
# All male silver medalists for all teams
Silver_M = df_M.loc[df_M["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_M.head()
# Out:
#     ID                  Name Sex   Age  Height  Weight           Team  \
# 18  25      Alf Lied Aanning   M  24.0     NaN     NaN         Norway
# 20  30      Pepijn Aardewijn   M  26.0   189.0    72.0    Netherlands
# 22  38          Karl Jan Aas   M  20.0     NaN     NaN         Norway
# 34  73             Luc Abalo   M  31.0   182.0    86.0         France
# 37  84  Stephen Anthony Abas   M  26.0   165.0    55.0  United States
#
#           Games            City       Sport  \
# 18  1920 Summer       Antwerpen  Gymnastics
# 20  1996 Summer         Atlanta      Rowing
# 22  1920 Summer       Antwerpen  Gymnastics
# 34  2016 Summer  Rio de Janeiro    Handball
# 37  2004 Summer          Athina   Wrestling
#
#                                             Event   Medal
# 18  Gymnastics Men's Team All-Around, Free System  Silver
# 20         Rowing Men's Lightweight Double Sculls  Silver
# 22  Gymnastics Men's Team All-Around, Free System  Silver
# 34                        Handball Men's Handball  Silver
# 37       Wrestling Men's Featherweight, Freestyle  Silver

# %%
# USA male silver medalists
USA_Silver_M = Silver_M.loc[Silver_M["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Silver_M.head()
# Out:
#        ID                          Name Sex   Age  Height  Weight  \
# 37     84          Stephen Anthony Abas   M  26.0   165.0    55.0
# 155   807  Benjamin Willard "Ben" Adams   M  22.0   188.0    78.0
# 157   813            Edgar Holmes Adams   M  36.0     NaN     NaN
# 164   836                   Platt Adams   M  27.0   188.0    78.0
# 204  1017        Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
#
#               Team        Games       City      Sport  \
# 37   United States  2004 Summer     Athina  Wrestling
# 155  United States  1912 Summer  Stockholm  Athletics
# 157  United States  1904 Summer  St. Louis   Swimming
# 164  United States  1912 Summer  Stockholm  Athletics
# 204  United States  2012 Summer     London   Swimming
#
#                                              Event   Medal
# 37        Wrestling Men's Featherweight, Freestyle  Silver
# 155             Athletics Men's Standing High Jump  Silver
# 157             Swimming Men's Plunge For Distance  Silver
# 164             Athletics Men's Standing Long Jump  Silver
# 204  Swimming Men's 4 x 100 metres Freestyle Relay  Silver

# %%
USA_Silver_M['Name'].value_counts()
# Out:
# Carl Townsend Osburn             4
# John Michael Plumb               4
# Gary Wayne Hall, Jr.             3
# Alexander Timothy "Tim" McKee    3
# Earl Foster Thomson              3
#                                 ..
# Ralph Vernon Mann                1
# Rodman Lewis "Rod" Wanamaker     1
# Steele Alexander Johnson         1
# David Matthew Dave Krmpotich     1
# James H. "Jim" Brady             1
# Name: Name, Length: 729, dtype: int64

# %%
USA_Silver_M_Name = USA_Silver_M['Name'].value_counts()
USA_Silver_M_Name = pd.DataFrame(USA_Silver_M_Name)
USA_Silver_M_Name.head()
# Out:
#                                Name
# Carl Townsend Osburn              4
# John Michael Plumb                4
# Gary Wayne Hall, Jr.              3
# Alexander Timothy "Tim" McKee     3
# Earl Foster Thomson               3

# %%
# Create bar chart for top USA male silver medalists
USA_Silver_M_Name_Chart = USA_Silver_M_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=0, color='silver')
USA_Silver_M_Name_Chart.set_ylabel("Medals Won")
USA_Silver_M_Name_Chart.set_title("USA Men's Silver Medals - Athlete Name")
plt.savefig('images/USA_Silver_M_Name.png')
plt.show()
plt.tight_layout()

# %%
# All male bronze medalists for all teams
Bronze_M = df_M.loc[df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_M.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  \
# 1   15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 2   15     Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland
# 4   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 8   17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
# 27  62        Giovanni Abagnale   M  21.0   198.0    90.0    Italy
#
#           Games            City       Sport  \
# 1   1920 Summer       Antwerpen    Swimming
# 2   1920 Summer       Antwerpen    Swimming
# 4   1948 Summer          London  Gymnastics
# 8   1952 Summer        Helsinki  Gymnastics
# 27  2016 Summer  Rio de Janeiro      Rowing
#
#                                      Event   Medal
# 1   Swimming Men's 200 metres Breaststroke  Bronze
# 2   Swimming Men's 400 metres Breaststroke  Bronze
# 4   Gymnastics Men's Individual All-Around  Bronze
# 8         Gymnastics Men's Team All-Around  Bronze
# 27              Rowing Men's Coxless Pairs  Bronze

# %%
# USA bronze medalists
USA_Bronze_M = Bronze_M.loc[Bronze_M["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Bronze_M.head()
# Out:
#        ID                          Name Sex   Age  Height  Weight  \
# 156   807  Benjamin Willard "Ben" Adams   M  22.0   188.0    78.0
# 206  1017        Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 207  1017        Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 462  2552    Hugh Vincenzo Alessandroni   M  24.0     NaN     NaN
# 524  2833               John Chad Allen   M  21.0   185.0    86.0
#
#               Team        Games            City      Sport  \
# 156  United States  1912 Summer       Stockholm  Athletics
# 206  United States  2016 Summer  Rio de Janeiro   Swimming
# 207  United States  2016 Summer  Rio de Janeiro   Swimming
# 462  United States  1932 Summer     Los Angeles    Fencing
# 524  United States  1996 Summer         Atlanta   Baseball
#
#                                    Event   Medal
# 156   Athletics Men's Standing Long Jump  Bronze
# 206   Swimming Men's 50 metres Freestyle  Bronze
# 207  Swimming Men's 100 metres Freestyle  Bronze
# 462             Fencing Men's Foil, Team  Bronze
# 524              Baseball Men's Baseball  Bronze

# %%
USA_Bronze_M['Name'].value_counts()
# Out:
# Robert Jeffrey Dover           4
# William G. Merz                4
# George Charles Calnan          3
# Ryan Steven Lochte             3
# Edwin "Teddy" Billington       3
#                               ..
# James Henry "Jim" Duncan       1
# Richard Lee "Dick" Cochran     1
# Charles John Horter            1
# Donald "Donny" Robinson        1
# Danell Johan Leyva Gonzalez    1
# Name: Name, Length: 700, dtype: int64

# %%
USA_Bronze_M_Name = USA_Bronze_M['Name'].value_counts()
USA_Bronze_M_Name = pd.DataFrame(USA_Bronze_M_Name)
USA_Bronze_M_Name.head()
# Out:
#                           Name
# Robert Jeffrey Dover         4
# William G. Merz              4
# George Charles Calnan        3
# Ryan Steven Lochte           3
# Edwin "Teddy" Billington     3

# %%
# Create bar chart for top USA male bronze medalists
USA_Bronze_M_Name_Chart = USA_Bronze_M_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=0, color='#b08d57')
USA_Bronze_M_Name_Chart.set_ylabel("Medals Won")
USA_Bronze_M_Name_Chart.set_title("USA Men's Bronze Medals - Athlete Name")
plt.savefig('images/USA_Bronze_M_Name.png')
plt.show()
plt.tight_layout()

# %%
# All female medalists for all teams
df_F = Summer_df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

df_F.head()
# Out:
#     ID                                     Name Sex   Age  Height  Weight  \
# 17  21                Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 19  29                     Willemien Aardenburg   F  22.0     NaN     NaN
# 21  37                       Ann Kristin Aarnes   F  23.0   182.0    64.0
# 29  65                        Patimat Abakarova   F  21.0   165.0    49.0
# 30  67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
#
#            Team        Games            City      Sport  \
# 17       Norway  2008 Summer         Beijing   Handball
# 19  Netherlands  1988 Summer           Seoul     Hockey
# 21       Norway  1996 Summer         Atlanta   Football
# 29   Azerbaijan  2016 Summer  Rio de Janeiro  Taekwondo
# 30       Russia  2008 Summer         Beijing  Athletics
#
#                               Event   Medal
# 17        Handball Women's Handball    Gold
# 19            Hockey Women's Hockey  Bronze
# 21        Football Women's Football  Bronze
# 29      Taekwondo Women's Flyweight  Bronze
# 30  Athletics Women's Javelin Throw  Silver

# %%
df_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    9442.000000  9425.000000  8757.000000  8667.000000
# mean    71364.609193    24.378992   171.105401    63.577305
# std     39037.103769     5.345236     9.307876    11.091268
# min        21.000000    11.000000   136.000000    28.000000
# 25%     38074.500000    21.000000   165.000000    57.000000
# 50%     70612.000000    24.000000   171.000000    63.000000
# 75%    106693.250000    27.000000   177.000000    70.000000
# max    135563.000000    69.000000   210.000000   167.000000

# %%
# All female gold medalists for all teams
Gold_F = df_F.loc[df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_F.head()
# Out:
#       ID                                  Name Sex   Age  Height  Weight  \
# 17    21             Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 57   150         Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 161  832                 Nicola Virginia Adams   F  29.0   164.0    51.0
# 162  832                 Nicola Virginia Adams   F  33.0   164.0    51.0
# 167  846  Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0   120.0
#
#               Team        Games            City      Sport  \
# 17          Norway  2008 Summer         Beijing   Handball
# 57   United States  1900 Summer           Paris       Golf
# 161  Great Britain  2012 Summer          London     Boxing
# 162  Great Britain  2016 Summer  Rio de Janeiro     Boxing
# 167    New Zealand  2008 Summer         Beijing  Athletics
#
#                           Event Medal
# 17    Handball Women's Handball  Gold
# 57      Golf Women's Individual  Gold
# 161    Boxing Women's Flyweight  Gold
# 162    Boxing Women's Flyweight  Gold
# 167  Athletics Women's Shot Put  Gold

# %%
Gold_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    3140.000000  3137.000000  2915.000000  2875.000000
# mean    71463.900318    24.211986   171.381818    63.795652
# std     39459.427238     5.288369     9.461007    11.442972
# min        21.000000    13.000000   136.000000    28.000000
# 25%     36758.000000    21.000000   165.000000    57.000000
# 50%     71056.500000    24.000000   172.000000    63.000000
# 75%    107494.000000    27.000000   178.000000    70.000000
# max    135553.000000    63.000000   210.000000   136.000000

# %%
# USA female gold medalists
USA_Gold_F = Gold_F.loc[df["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

USA_Gold_F.head()
# Out:
#        ID                                             Name Sex   Age  Height  \
# 57    150                    Margaret Ives Abbott (-Dunne)   F  23.0     NaN
# 274  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 276  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 347  1622                              Michelle Anne Akers   F  30.0   178.0
# 366  1682                                Morolake Akinosun   F  22.0   163.0
#
#      Weight           Team        Games            City      Sport  \
# 57      NaN  United States  1900 Summer           Paris       Golf
# 274    52.0  United States  1992 Summer       Barcelona   Swimming
# 276    52.0  United States  1992 Summer       Barcelona   Swimming
# 347    68.0  United States  1996 Summer         Atlanta   Football
# 366    61.0  United States  2016 Summer  Rio de Janeiro  Athletics
#
#                                                Event Medal
# 57                           Golf Women's Individual  Gold
# 274  Swimming Women's 4 x 100 metres Freestyle Relay  Gold
# 276     Swimming Women's 4 x 100 metres Medley Relay  Gold
# 347                        Football Women's Football  Gold
# 366           Athletics Women's 4 x 100 metres Relay  Gold

# %%
USA_Gold_F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 773 entries, 57 to 39196
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      773 non-null    int64
#  1   Name    773 non-null    object
#  2   Sex     773 non-null    object
#  3   Age     773 non-null    float64
#  4   Height  732 non-null    float64
#  5   Weight  716 non-null    float64
#  6   Team    773 non-null    object
#  7   Games   773 non-null    object
#  8   City    773 non-null    object
#  9   Sport   773 non-null    object
#  10  Event   773 non-null    object
#  11  Medal   773 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 78.5+ KB

# %%
USA_Gold_F['Name'].value_counts()
# Out:
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    8
# Amy Deloris Van Dyken (-Rouen)                     6
# Allyson Michelle Felix                             6
# Dana Whitney Vollmer (-Grant)                      5
# Kathleen Genevieve "Katie" Ledecky                 5
#                                                   ..
# Ashleigh Johnson                                   1
# Janice Faye Lawrence (-Braxton)                    1
# Frances Cowells Schroth                            1
# Diamond Brittany Dixon                             1
# Megan Adelle Kleine (-Morris)                      1
# Name: Name, Length: 503, dtype: int64

# %%
USA_Gold_F_Name = USA_Gold_F['Name'].value_counts()
USA_Gold_F_Name = pd.DataFrame(USA_Gold_F_Name)
USA_Gold_F_Name.head(10)
# Out:
#                                                  Name
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     8
# Amy Deloris Van Dyken (-Rouen)                      6
# Allyson Michelle Felix                              6
# Dana Whitney Vollmer (-Grant)                       5
# Kathleen Genevieve "Katie" Ledecky                  5

# %%
# Create bar chart for top USA female gold medalists
USA_Gold_F_Name_Chart = USA_Gold_F_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=10, color='gold')
USA_Gold_F_Name_Chart.set_ylabel("Medals Won")
USA_Gold_F_Name_Chart.set_title("USA Women's Gold Medals - Athlete Name")
plt.savefig('images/USA_Gold_F_Name.png')
plt.show()
plt.tight_layout()

# %%
USA_Gold_F['Sport'].value_counts()
# Out:
# Swimming                 264
# Athletics                128
# Basketball                95
# Football                  66
# Softball                  45
# Rowing                    36
# Gymnastics                28
# Water Polo                25
# Diving                    20
# Synchronized Swimming     16
# Tennis                    13
# Equestrianism              8
# Shooting                   8
# Cycling                    4
# Archery                    4
# Sailing                    3
# Boxing                     2
# Fencing                    2
# Judo                       2
# Wrestling                  1
# Triathlon                  1
# Golf                       1
# Weightlifting              1
# Name: Sport, dtype: int64

# %%
USA_Gold_F_Sports = USA_Gold_F['Sport'].value_counts()

# %%
USA_Gold_F_df = pd.DataFrame(USA_Gold_F_Sports)
USA_Gold_F_df.head()
# Out:
#             Sport
# Swimming      264
# Athletics     128
# Basketball     95
# Football       66
# Softball       45

# %%
# All female silver medalists for all teams
Silver_F = df_F.loc[df["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_F.head()
# Out:
#      ID                                     Name Sex   Age  Height  Weight  \
# 30   67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 40   90                Tamila Rashidovna Abasova   F  21.0   163.0    60.0
# 58  153                    Monica Cecilia Abbott   F  23.0   191.0    88.0
# 59  165                      Nia Nicole Abdallah   F  20.0   175.0    56.0
# 76  394                               Irene Abel   F  19.0   160.0    48.0
#
#              Team        Games     City       Sport  \
# 30         Russia  2008 Summer  Beijing   Athletics
# 40         Russia  2004 Summer   Athina     Cycling
# 58  United States  2008 Summer  Beijing    Softball
# 59  United States  2004 Summer   Athina   Taekwondo
# 76   East Germany  1972 Summer   Munich  Gymnastics
#
#                                  Event   Medal
# 30     Athletics Women's Javelin Throw  Silver
# 40              Cycling Women's Sprint  Silver
# 58           Softball Women's Softball  Silver
# 59     Taekwondo Women's Featherweight  Silver
# 76  Gymnastics Women's Team All-Around  Silver

# %%
# USA female silver medalists
USA_Silver_F = Silver_F.loc[Silver_F["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Silver_F.head()
# Out:
#        ID                                             Name Sex   Age  Height  \
# 58    153                            Monica Cecilia Abbott   F  23.0   191.0
# 59    165                              Nia Nicole Abdallah   F  20.0   175.0
# 256  1313                     Robyn Mokihana Ah Mow-Santos   F  32.0   172.0
# 275  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 367  1683                       Foluke Antinuke Akinradewo   F  24.0   191.0
#
#      Weight           Team        Games       City       Sport  \
# 58     88.0  United States  2008 Summer    Beijing    Softball
# 59     56.0  United States  2004 Summer     Athina   Taekwondo
# 256    67.0  United States  2008 Summer    Beijing  Volleyball
# 275    52.0  United States  1992 Summer  Barcelona    Swimming
# 367    79.0  United States  2012 Summer     London  Volleyball
#
#                                      Event   Medal
# 58               Softball Women's Softball  Silver
# 59         Taekwondo Women's Featherweight  Silver
# 256          Volleyball Women's Volleyball  Silver
# 275  Swimming Women's 100 metres Butterfly  Silver
# 367          Volleyball Women's Volleyball  Silver

# %%
USA_Silver_F['Name'].value_counts()
# Out:
# Shirley Frances Babashoff               6
# Kara Lynn Joyce                         4
# Dara Grace Torres (-Hoffman, -Minas)    4
# Natalie Anne Coughlin (-Hall)           4
# Amanda Ray Beard (-Brown)               4
#                                        ..
# Patricia Sue "Pat" Head (-Summitt)      1
# Pauline "Polly" Whittier (-Iselin)      1
# Mary Rebecca Whipple                    1
# Lauren Zoe "Laurie" Hernandez           1
# Tiffeny Carleen Milbrett                1
# Name: Name, Length: 352, dtype: int64

# %%
USA_Silver_F_Name = USA_Silver_F['Name'].value_counts()
USA_Silver_F_Name = pd.DataFrame(USA_Silver_F_Name)
USA_Silver_F_Name.head()
# Out:
#                                       Name
# Shirley Frances Babashoff                6
# Kara Lynn Joyce                          4
# Dara Grace Torres (-Hoffman, -Minas)     4
# Natalie Anne Coughlin (-Hall)            4
# Amanda Ray Beard (-Brown)                4

# %%
# Create bar chart for top USA female silver medalists
USA_Silver_F_Name_Chart = USA_Silver_F_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=10, color='silver')
USA_Silver_F_Name_Chart.set_ylabel("Medals Won")
USA_Silver_F_Name_Chart.set_title("USA Women's Silver Medals - Athlete Name")
plt.savefig('images/USA_Silver_F_Name.png')
plt.show()
plt.tight_layout()

# %%
# All female bronze medalists for all teams
Bronze_F = df_F.loc[df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_F.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  \
# 19   29  Willemien Aardenburg   F  22.0     NaN     NaN  Netherlands
# 21   37    Ann Kristin Aarnes   F  23.0   182.0    64.0       Norway
# 29   65     Patimat Abakarova   F  21.0   165.0    49.0   Azerbaijan
# 61  259            Reema Abdo   F  21.0   173.0    59.0       Canada
# 77  395         Jennifer Abel   F  20.0   160.0    62.0       Canada
#
#           Games            City      Sport  \
# 19  1988 Summer           Seoul     Hockey
# 21  1996 Summer         Atlanta   Football
# 29  2016 Summer  Rio de Janeiro  Taekwondo
# 61  1984 Summer     Los Angeles   Swimming
# 77  2012 Summer          London     Diving
#
#                                            Event   Medal
# 19                         Hockey Women's Hockey  Bronze
# 21                     Football Women's Football  Bronze
# 29                   Taekwondo Women's Flyweight  Bronze
# 61  Swimming Women's 4 x 100 metres Medley Relay  Bronze
# 77       Diving Women's Synchronized Springboard  Bronze

# %%
# USA female bronze medalists
USA_Bronze_F = Bronze_F.loc[Bronze_F["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Bronze_F.head()
# Out:
#        ID                              Name Sex   Age  Height  Weight  \
# 165   837              Rachael Alexis Adams   F  26.0   188.0    81.0
# 368  1683        Foluke Antinuke Akinradewo   F  28.0   191.0    79.0
# 374  1730                    Monica Aksamit   F  26.0   183.0    74.0
# 437  2443  Joan "Jody" Alderson (-Braskamp)   F  17.0   170.0    59.0
# 720  3681     Elizabeth Rambo "Beth" Anders   F  32.0   174.0    73.0
#
#               Team        Games            City       Sport  \
# 165  United States  2016 Summer  Rio de Janeiro  Volleyball
# 368  United States  2016 Summer  Rio de Janeiro  Volleyball
# 374  United States  2016 Summer  Rio de Janeiro     Fencing
# 437  United States  1952 Summer        Helsinki    Swimming
# 720  United States  1984 Summer     Los Angeles      Hockey
#
#                                                Event   Medal
# 165                    Volleyball Women's Volleyball  Bronze
# 368                    Volleyball Women's Volleyball  Bronze
# 374                      Fencing Women's Sabre, Team  Bronze
# 437  Swimming Women's 4 x 100 metres Freestyle Relay  Bronze
# 720                            Hockey Women's Hockey  Bronze

# %%
USA_Bronze_F['Name'].value_counts()
# Out:
# Natalie Anne Coughlin (-Hall)                  5
# Dara Grace Torres (-Hoffman, -Minas)           4
# Dominique Margaux Dawes (-Thompson)            3
# Angelina L. "Angel" Martino (Myers-, -Sims)    3
# Shannon Lee Miller (-Phillips, -Falconetti)    3
#                                               ..
# Deborah Keplar "Debbie" Wilson                 1
# Georgia V. Coleman (-Gilson)                   1
# Lynn Silliman                                  1
# Susan Marie DeMattei (-Wiens)                  1
# Dorothy Sarkis Morkis                          1
# Name: Name, Length: 308, dtype: int64

# %%
USA_Bronze_F_Name = USA_Bronze_F['Name'].value_counts()
USA_Bronze_F_Name = pd.DataFrame(USA_Bronze_F_Name)
USA_Bronze_F_Name.head()
# Out:
#                                              Name
# Natalie Anne Coughlin (-Hall)                   5
# Dara Grace Torres (-Hoffman, -Minas)            4
# Dominique Margaux Dawes (-Thompson)             3
# Angelina L. "Angel" Martino (Myers-, -Sims)     3
# Shannon Lee Miller (-Phillips, -Falconetti)     3

# %%
# Create bar chart for top USA female bronze medalists
USA_Bronze_F_Name_Chart = USA_Bronze_F_Name.head(5).plot(kind='bar', figsize=(15, 9), rot=10, color='#b08d57')
USA_Bronze_F_Name_Chart.set_ylabel("Medals Won") 
USA_Bronze_F_Name_Chart.set_title("USA Women's Bronze Medals - Athlete Name")
plt.savefig('images/USA_Bronze_F_Name.png')
plt.show()
plt.tight_layout()

# %%
# All USA medalists
USA_df = Summer_df.loc[df["Team"] == "United States", :]
USA_df.head()
# Out:
#      ID                           Name Sex   Age  Height  Weight  \
# 37   84           Stephen Anthony Abas   M  26.0   165.0    55.0
# 57  150  Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 58  153          Monica Cecilia Abbott   F  23.0   191.0    88.0
# 59  165            Nia Nicole Abdallah   F  20.0   175.0    56.0
# 68  351     Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
#
#              Team  NOC        Games  Year  Season     City       Sport  \
# 37  United States  USA  2004 Summer  2004  Summer   Athina   Wrestling
# 57  United States  USA  1900 Summer  1900  Summer    Paris        Golf
# 58  United States  USA  2008 Summer  2008  Summer  Beijing    Softball
# 59  United States  USA  2004 Summer  2004  Summer   Athina   Taekwondo
# 68  United States  USA  2000 Summer  2000  Summer   Sydney  Basketball
#
#                                        Event   Medal
# 37  Wrestling Men's Featherweight, Freestyle  Silver
# 57                   Golf Women's Individual    Gold
# 58                 Softball Women's Softball  Silver
# 59           Taekwondo Women's Featherweight  Silver
# 68               Basketball Men's Basketball    Gold

# %%
USA_df['Medal'].value_counts()
# Out:
# Gold      2333
# Silver    1241
# Bronze    1112
# Name: Medal, dtype: int64

# %%
USA_df['Sport'].value_counts().head()
# Out:
# Athletics     1071
# Swimming      1066
# Basketball     341
# Rowing         333
# Shooting       193
# Name: Sport, dtype: int64

# %%
# USA men's gold analysis

USA_Gold_M['Medal'].value_counts()
# Out:
# Gold    1560
# Name: Medal, dtype: int64

# %%
USA_Gold_M['Sport'].value_counts()
# Out:
# Athletics           409
# Swimming            381
# Basketball          186
# Rowing              124
# Shooting            109
# Wrestling            51
# Boxing               48
# Volleyball           36
# Rugby                35
# Diving               28
# Gymnastics           27
# Baseball             24
# Equestrianism        22
# Sailing              21
# Weightlifting        15
# Cycling              12
# Archery              10
# Canoeing              6
# Tennis                5
# Art Competitions      4
# Taekwondo             2
# Fencing               2
# Roque                 1
# Golf                  1
# Jeu De Paume          1
# Name: Sport, dtype: int64

# %%
USA_Gold_M_Sports = USA_Gold_M['Sport'].value_counts()
USA_Gold_M_Sports = pd.DataFrame(USA_Gold_M_Sports)
USA_Gold_M_Sports.head(10)
# Out:
#             Sport
# Athletics     409
# Swimming      381
# Basketball    186
# Rowing        124
# Shooting      109
# Wrestling      51
# Boxing         48
# Volleyball     36
# Rugby          35
# Diving         28

# %%
# Create bar chart for top USA men's gold sports
USA_Gold_M_Sports_Chart = USA_Gold_M_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='gold')
USA_Gold_M_Sports_Chart.set_ylabel("Medals Won")
USA_Gold_M_Sports_Chart.set_title("USA Men's Gold Medals - Sport")
plt.savefig('images/USA_Gold_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
# USA men's silver analysis

USA_Silver_M['Medal'].value_counts()
# Out:
# Silver    822
# Name: Medal, dtype: int64

# %%
USA_Silver_M['Sport'].value_counts()
# Out:
# Athletics            250
# Swimming             130
# Rowing                66
# Wrestling             41
# Water Polo            39
# Equestrianism         36
# Sailing               34
# Shooting              33
# Gymnastics            30
# Diving                24
# Boxing                24
# Cycling               17
# Weightlifting         16
# Fencing               14
# Archery               13
# Basketball            12
# Ice Hockey            11
# Modern Pentathlon     11
# Art Competitions       4
# Polo                   4
# Judo                   4
# Canoeing               3
# Tennis                 3
# Taekwondo              1
# Golf                   1
# Roque                  1
# Name: Sport, dtype: int64

# %%
USA_Silver_M_Sports = USA_Silver_M['Sport'].value_counts()
USA_Silver_M_Sports = pd.DataFrame(USA_Silver_M_Sports)
USA_Silver_M_Sports.head()
# Out:
#             Sport
# Athletics     250
# Swimming      130
# Rowing         66
# Wrestling      41
# Water Polo     39

# %%
# Create bar chart for top USA men's silver sports
USA_Silver_M_Sports_Chart = USA_Silver_M_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='silver')
USA_Silver_M_Sports_Chart.set_ylabel("Medals Won")
USA_Silver_M_Sports_Chart.set_title("USA Men's Silver Medals - Sport")
plt.savefig('images/USA_Silver_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
# USA men's bronze analysis
USA_Bronze_M['Medal'].value_counts()
# Out:
# Bronze    769
# Name: Medal, dtype: int64

# %%
USA_Bronze_M['Sport'].value_counts()
# Out:
# Athletics            184
# Swimming              84
# Rowing                61
# Baseball              44
# Boxing                38
# Shooting              35
# Fencing               34
# Equestrianism         32
# Wrestling             31
# Water Polo            27
# Cycling               26
# Gymnastics            26
# Diving                25
# Volleyball            24
# Basketball            24
# Sailing               17
# Hockey                14
# Weightlifting          8
# Archery                7
# Judo                   6
# Modern Pentathlon      5
# Canoeing               4
# Polo                   4
# Tennis                 3
# Golf                   3
# Taekwondo              2
# Roque                  1
# Name: Sport, dtype: int64

# %%
USA_Bronze_M_Sports = USA_Bronze_M['Sport'].value_counts()
USA_Bronze_M_Sports = pd.DataFrame(USA_Bronze_M_Sports)
USA_Bronze_M_Sports.head()
# Out:
#            Sport
# Athletics    184
# Swimming      84
# Rowing        61
# Baseball      44
# Boxing        38

# %%
# Create bar chart for top USA men's bronze sports
USA_Bronze_M_Sports_Chart = USA_Bronze_M_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='#b08d57')
USA_Bronze_M_Sports_Chart.set_ylabel("Medals Won")
USA_Bronze_M_Sports_Chart.set_title("USA Men's Bronze Medals - Sport")
plt.savefig('images/USA_Bronze_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Women's Gold Analysis

USA_Gold_F['Medal'].value_counts()
# Out:
# Gold    773
# Name: Medal, dtype: int64

# %%
USA_Gold_F['Sport'].value_counts()
# Out:
# Swimming                 264
# Athletics                128
# Basketball                95
# Football                  66
# Softball                  45
# Rowing                    36
# Gymnastics                28
# Water Polo                25
# Diving                    20
# Synchronized Swimming     16
# Tennis                    13
# Equestrianism              8
# Shooting                   8
# Cycling                    4
# Archery                    4
# Sailing                    3
# Boxing                     2
# Fencing                    2
# Judo                       2
# Wrestling                  1
# Triathlon                  1
# Golf                       1
# Weightlifting              1
# Name: Sport, dtype: int64

# %%
USA_Gold_F_Sports = USA_Gold_F['Sport'].value_counts()
USA_Gold_F_Sports = pd.DataFrame(USA_Gold_F_Sports)
USA_Gold_F_Sports.head()
# Out:
#             Sport
# Swimming      264
# Athletics     128
# Basketball     95
# Football       66
# Softball       45

# %%
# Create bar chart for top USA women's gold sports
USA_Gold_F_Sports_Chart = USA_Gold_F_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='gold')
USA_Gold_F_Sports_Chart.set_ylabel("Medals Won")
USA_Gold_F_Sports_Chart.set_title("USA Women's Gold Medals - Sport")
plt.savefig('images/USA_Gold_F_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Women's Silver Analysis

USA_Silver_F['Medal'].value_counts()
# Out:
# Silver    419
# Name: Medal, dtype: int64

# %%
USA_Silver_F['Sport'].value_counts()
# Out:
# Swimming                 120
# Athletics                 63
# Volleyball                36
# Gymnastics                35
# Rowing                    27
# Water Polo                26
# Diving                    22
# Softball                  15
# Cycling                   14
# Football                  13
# Equestrianism             13
# Basketball                12
# Fencing                    4
# Canoeing                   4
# Synchronized Swimming      3
# Shooting                   3
# Archery                    2
# Sailing                    2
# Wrestling                  1
# Art Competitions           1
# Taekwondo                  1
# Golf                       1
# Modern Pentathlon          1
# Name: Sport, dtype: int64

# %%
USA_Silver_F_Sports = USA_Silver_F['Sport'].value_counts()
USA_Silver_F_Sports = pd.DataFrame(USA_Silver_F_Sports)
USA_Silver_F_Sports.head()
# Out:
#             Sport
# Swimming      120
# Athletics      63
# Volleyball     36
# Gymnastics     35
# Rowing         27

# %%
# Create bar chart for top USA women's silver sports
USA_Silver_F_Sports_Chart = USA_Silver_F_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='silver')
USA_Silver_F_Sports_Chart.set_ylabel("Medals Won")
USA_Silver_F_Sports_Chart.set_title("USA Women's Silver Medals - Sport")
plt.savefig('images/USA_Silver_F_Sports.png')
plt.show()
plt.tight_layout()

# %%
# USA women's bronze analysis
USA_Bronze_F['Medal'].value_counts()
# Out:
# Bronze    343
# Name: Medal, dtype: int64

# %%
USA_Bronze_F['Sport'].value_counts()
# Out:
# Swimming                 87
# Athletics                37
# Gymnastics               31
# Volleyball               24
# Equestrianism            21
# Diving                   21
# Rowing                   19
# Hockey                   16
# Fencing                  13
# Basketball               12
# Water Polo               12
# Synchronized Swimming    11
# Cycling                   5
# Archery                   5
# Shooting                  5
# Tennis                    4
# Sailing                   4
# Taekwondo                 3
# Wrestling                 3
# Canoeing                  2
# Judo                      2
# Weightlifting             2
# Boxing                    1
# Golf                      1
# Figure Skating            1
# Triathlon                 1
# Name: Sport, dtype: int64

# %%
USA_Bronze_F_Sports = USA_Bronze_F['Sport'].value_counts()
USA_Bronze_F_Sports = pd.DataFrame(USA_Bronze_F_Sports)
USA_Bronze_F_Sports.head()
# Out:
#                Sport
# Swimming          87
# Athletics         37
# Gymnastics        31
# Volleyball        24
# Equestrianism     21

# %%
# Create bar chart for top USA women's bronze sports
USA_Bronze_F_Sports_Chart = USA_Bronze_F_Sports.head(10).plot(kind='bar', figsize=(14, 7), rot=0, color='#b08d57')
USA_Bronze_F_Sports_Chart.set_ylabel("Medals Won")
USA_Bronze_F_Sports_Chart.set_title("USA Women's Bronze Medals - Sport")
plt.savefig('images/USA_Bronze_F_Sports.png')
plt.show()
plt.tight_layout()

# %%
# Most medals won - all teams
Most_Team_Medals = Summer_df['Team'].value_counts()
Most_Team_Medals.head(25)
# Out:
# United States    4686
# Soviet Union     2061
# Germany          1687
# Great Britain    1598
# France           1408
# Italy            1384
# Australia        1290
# Hungary          1123
# Sweden           1006
# Russia            894
# Netherlands       866
# Japan             848
# East Germany      841
# China             831
# Canada            668
# Romania           651
# Denmark           548
# Poland            536
# South Korea       506
# West Germany      502
# Spain             481
# Norway            467
# Finland           450
# Brazil            449
# Cuba              407
# Name: Team, dtype: int64

# %%
# Create bar chart for most team medals won
Most_Team_Medals_Chart = Most_Team_Medals.head(10).plot(kind='bar', figsize=(12, 9), rot=0, color='steelblue')
Most_Team_Medals_Chart.set_ylabel("Medals Won")
Most_Team_Medals_Chart.set_title("Most Team Medals Won Since 1896")
plt.savefig('images/Most_Team_Medals.png')
plt.show()
plt.tight_layout()

# %%
# Medal ratio analysis

# %%
USA_Medals = Summer_df.loc[df["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

USA_Medals['Medal'].value_counts()
# Out:
# Gold      2333
# Silver    1241
# Bronze    1112
# Name: Medal, dtype: int64

# %%
Soviet_Union_Medals = Summer_df.loc[df["Team"] == "Soviet Union", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Soviet_Union_Medals['Medal'].value_counts()
# Out:
# Gold      830
# Silver    635
# Bronze    596
# Name: Medal, dtype: int64

# %%
Germany_Medals = Summer_df.loc[df["Team"] == "Germany", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Germany_Medals['Medal'].value_counts()
# Out:
# Bronze    610
# Gold      564
# Silver    513
# Name: Medal, dtype: int64

# %%
Great_Britain_Medals = Summer_df.loc[df["Team"] == "Great Britain", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Great_Britain_Medals['Medal'].value_counts()
# Out:
# Silver    576
# Bronze    541
# Gold      481
# Name: Medal, dtype: int64

# %%
France_Medals = Summer_df.loc[df["Team"] == "France", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

France_Medals['Medal'].value_counts()
# Out:
# Bronze    502
# Silver    485
# Gold      421
# Name: Medal, dtype: int64

# %%
Italy_Medals = Summer_df.loc[df["Team"] == "Italy", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Italy_Medals['Medal'].value_counts()
# Out:
# Gold      492
# Silver    467
# Bronze    425
# Name: Medal, dtype: int64

# %%
Australia_Medals = Summer_df.loc[df["Team"] == "Australia", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Australia_Medals['Medal'].value_counts()
# Out:
# Bronze    504
# Silver    450
# Gold      336
# Name: Medal, dtype: int64

# %%
Hungary_Medals = Summer_df.loc[df["Team"] == "Hungary", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Hungary_Medals['Medal'].value_counts()
# Out:
# Gold      432
# Bronze    363
# Silver    328
# Name: Medal, dtype: int64

# %%
Sweden_Medals = Summer_df.loc[df["Team"] == "Sweden", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Sweden_Medals['Medal'].value_counts()
# Out:
# Silver    350
# Bronze    330
# Gold      326
# Name: Medal, dtype: int64

# %%
Russia_Medals = Summer_df.loc[df["Team"] == "Russia", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Russia_Medals['Medal'].value_counts()
# Out:
# Bronze    322
# Gold      294
# Silver    278
# Name: Medal, dtype: int64

# %%
# Create a seperate df to create a csv with no null values for SQL
df_SQL = df
df_SQL.dropna(inplace=True)
df_SQL.to_csv("olympics2.csv", index=False)
