# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib

# %%
# Read CSV
df = pd.read_csv("athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df.to_csv("olympics2.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30181 entries, 40 to 271103
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      30181 non-null  int64
#  1   Name    30181 non-null  object
#  2   Sex     30181 non-null  object
#  3   Age     30181 non-null  float64
#  4   Height  30181 non-null  float64
#  5   Weight  30181 non-null  float64
#  6   Team    30181 non-null  object
#  7   NOC     30181 non-null  object
#  8   Games   30181 non-null  object
#  9   Year    30181 non-null  int64
#  10  Season  30181 non-null  object
#  11  City    30181 non-null  object
#  12  Sport   30181 non-null  object
#  13  Event   30181 non-null  object
#  14  Medal   30181 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 3.7+ MB

# %%
# Drop All Non Medalists
df.dropna(subset= ['Medal'], inplace=True)

# %%
df.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
# 48  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30181 entries, 40 to 271103
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      30181 non-null  int64
#  1   Name    30181 non-null  object
#  2   Sex     30181 non-null  object
#  3   Age     30181 non-null  float64
#  4   Height  30181 non-null  float64
#  5   Weight  30181 non-null  float64
#  6   Team    30181 non-null  object
#  7   NOC     30181 non-null  object
#  8   Games   30181 non-null  object
#  9   Year    30181 non-null  int64
#  10  Season  30181 non-null  object
#  11  City    30181 non-null  object
#  12  Sport   30181 non-null  object
#  13  Event   30181 non-null  object
#  14  Medal   30181 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 3.7+ MB

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 0  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 1  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 2  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 3  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 4  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#          Games  Year  Season    City       Sport  \
# 0  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 1  1948 Summer  1948  Summer  London  Gymnastics
# 2  1948 Summer  1948  Summer  London  Gymnastics
# 3  1948 Summer  1948  Summer  London  Gymnastics
# 4  1948 Summer  1948  Summer  London  Gymnastics
#
#                                     Event   Medal
# 0             Ice Hockey Men's Ice Hockey  Bronze
# 1  Gymnastics Men's Individual All-Around  Bronze
# 2        Gymnastics Men's Team All-Around    Gold
# ...

# %%
### Select Summer Olympics Only

Summer_df = df.loc[df["Season"] == "Summer", :]
Summer_df.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight     Team  NOC  \
# 1  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 2  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 3  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 4  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 5  17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
#
#          Games  Year  Season      City       Sport  \
# 1  1948 Summer  1948  Summer    London  Gymnastics
# 2  1948 Summer  1948  Summer    London  Gymnastics
# 3  1948 Summer  1948  Summer    London  Gymnastics
# 4  1948 Summer  1948  Summer    London  Gymnastics
# 5  1952 Summer  1952  Summer  Helsinki  Gymnastics
#
#                                     Event   Medal
# 1  Gymnastics Men's Individual All-Around  Bronze
# 2        Gymnastics Men's Team All-Around    Gold
# 3            Gymnastics Men's Horse Vault    Gold
# ...

# %%
Summer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25341 entries, 1 to 30180
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      25341 non-null  int64
#  1   Name    25341 non-null  object
#  2   Sex     25341 non-null  object
#  3   Age     25341 non-null  float64
#  4   Height  25341 non-null  float64
#  5   Weight  25341 non-null  float64
#  6   Team    25341 non-null  object
#  7   NOC     25341 non-null  object
#  8   Games   25341 non-null  object
#  9   Year    25341 non-null  int64
#  10  Season  25341 non-null  object
#  11  City    25341 non-null  object
#  12  Sport   25341 non-null  object
#  13  Event   25341 non-null  object
#  14  Medal   25341 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 3.1+ MB

# %%
Summer_df.describe()
# Out:
#                   ID           Age        Height        Weight          Year
# count   25341.000000  25341.000000  25341.000000  25341.000000  25341.000000
# mean    70096.563829     25.317391    178.030307     73.940294   1987.042737
# std     38944.588897      5.121130     11.252503     15.353146     23.455194
# min        17.000000     13.000000    136.000000     28.000000   1896.000000
# 25%     37019.000000     22.000000    170.000000     63.000000   1972.000000
# 50%     69870.000000     25.000000    178.000000     73.000000   1992.000000
# 75%    104161.000000     28.000000    185.000000     83.000000   2004.000000
# max    135563.000000     66.000000    223.000000    182.000000   2016.000000

# %%
### All Teams Gold Medals Won

Gold_df = Summer_df.loc[Summer_df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_df.head()
# Out:
#     ID                              Name Sex   Age  Height  Weight     Team  \
# 2   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 3   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 4   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 20  72  Aleksey Aleksandrovich Abalmasov   M  28.0   180.0    83.0  Belarus
# 21  73                         Luc Abalo   M  23.0   182.0    86.0   France
#
#           Games     City       Sport  \
# 2   1948 Summer   London  Gymnastics
# 3   1948 Summer   London  Gymnastics
# 4   1948 Summer   London  Gymnastics
# 20  2008 Summer  Beijing    Canoeing
# 21  2008 Summer  Beijing    Handball
#
#                                        Event Medal
# 2           Gymnastics Men's Team All-Around  Gold
# 3               Gymnastics Men's Horse Vault  Gold
# 4           Gymnastics Men's Pommelled Horse  Gold
# 20  Canoeing Men's Kayak Fours, 1,000 metres  Gold
# ...

# %%
Gold_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8542 entries, 2 to 30175
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      8542 non-null   int64
#  1   Name    8542 non-null   object
#  2   Sex     8542 non-null   object
#  3   Age     8542 non-null   float64
#  4   Height  8542 non-null   float64
#  5   Weight  8542 non-null   float64
#  6   Team    8542 non-null   object
#  7   Games   8542 non-null   object
#  8   City    8542 non-null   object
#  9   Sport   8542 non-null   object
#  10  Event   8542 non-null   object
#  11  Medal   8542 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 867.5+ KB

# %%
Gold_df.describe()
# Out:
#                   ID          Age       Height       Weight
# count    8542.000000  8542.000000  8542.000000  8542.000000
# mean    70043.404823    25.200070   178.389253    74.307715
# std     39067.199923     5.100547    11.421037    15.505129
# min        17.000000    13.000000   136.000000    28.000000
# 25%     36492.000000    22.000000   170.000000    63.000000
# 50%     69800.000000    25.000000   178.000000    73.000000
# 75%    104184.750000    28.000000   186.000000    84.000000
# max    135553.000000    59.000000   223.000000   170.000000

# %%
### All Teams Silver Medals Won

Silver_df = Summer_df.loc[Summer_df["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_df.head()
# Out:
#     ID                                     Name Sex   Age  Height  Weight  \
# 14  30                         Pepijn Aardewijn   M  26.0   189.0    72.0
# 19  67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 23  73                                Luc Abalo   M  31.0   182.0    86.0
# 26  84                     Stephen Anthony Abas   M  26.0   165.0    55.0
# 29  90                Tamila Rashidovna Abasova   F  21.0   163.0    60.0
#
#              Team        Games            City      Sport  \
# 14    Netherlands  1996 Summer         Atlanta     Rowing
# 19         Russia  2008 Summer         Beijing  Athletics
# 23         France  2016 Summer  Rio de Janeiro   Handball
# 26  United States  2004 Summer          Athina  Wrestling
# 29         Russia  2004 Summer          Athina    Cycling
#
#                                        Event   Medal
# 14    Rowing Men's Lightweight Double Sculls  Silver
# 19           Athletics Women's Javelin Throw  Silver
# ...

# %%
Silver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8233 entries, 14 to 30180
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      8233 non-null   int64
#  1   Name    8233 non-null   object
#  2   Sex     8233 non-null   object
#  3   Age     8233 non-null   float64
#  4   Height  8233 non-null   float64
#  5   Weight  8233 non-null   float64
#  6   Team    8233 non-null   object
#  7   Games   8233 non-null   object
#  8   City    8233 non-null   object
#  9   Sport   8233 non-null   object
#  10  Event   8233 non-null   object
#  11  Medal   8233 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 836.2+ KB

# %%
Silver_df.describe()
# Out:
#                   ID          Age       Height       Weight
# count    8233.000000  8233.000000  8233.000000  8233.000000
# mean    69911.579133    25.355642   177.957124    73.809547
# std     38979.062203     5.161139    11.195388    15.149808
# min        30.000000    13.000000   136.000000    30.000000
# 25%     37194.000000    22.000000   170.000000    63.000000
# 50%     69689.000000    25.000000   178.000000    73.000000
# 75%    103926.000000    28.000000   185.000000    83.000000
# max    135563.000000    66.000000   223.000000   167.000000

# %%
### All Teams Bronze Medals Won

Bronze_df = Summer_df.loc[Summer_df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_df.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  \
# 1   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 5   17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
# 15  37       Ann Kristin Aarnes   F  23.0   182.0    64.0   Norway
# 16  62        Giovanni Abagnale   M  21.0   198.0    90.0    Italy
# 17  63      Jos Luis Abajo Gmez   M  30.0   194.0    87.0    Spain
#
#           Games            City       Sport  \
# 1   1948 Summer          London  Gymnastics
# 5   1952 Summer        Helsinki  Gymnastics
# 15  1996 Summer         Atlanta    Football
# 16  2016 Summer  Rio de Janeiro      Rowing
# 17  2008 Summer         Beijing     Fencing
#
#                                      Event   Medal
# 1   Gymnastics Men's Individual All-Around  Bronze
# 5         Gymnastics Men's Team All-Around  Bronze
# 15               Football Women's Football  Bronze
# 16              Rowing Men's Coxless Pairs  Bronze
# ...

# %%
Bronze_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8566 entries, 1 to 30179
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      8566 non-null   int64
#  1   Name    8566 non-null   object
#  2   Sex     8566 non-null   object
#  3   Age     8566 non-null   float64
#  4   Height  8566 non-null   float64
#  5   Weight  8566 non-null   float64
#  6   Team    8566 non-null   object
#  7   Games   8566 non-null   object
#  8   City    8566 non-null   object
#  9   Sport   8566 non-null   object
#  10  Event   8566 non-null   object
#  11  Medal   8566 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 870.0+ KB

# %%
Bronze_df.describe()
# Out:
#                   ID          Age       Height       Weight
# count    8566.000000  8566.000000  8566.000000  8566.000000
# mean    70327.367383    25.397618   177.742704    73.699568
# std     38792.087159     5.101466    11.128958    15.389920
# min        17.000000    13.000000   136.000000    28.000000
# 25%     37560.250000    22.000000   170.000000    63.000000
# 50%     70221.500000    25.000000   178.000000    72.000000
# 75%    104352.500000    28.000000   185.000000    82.000000
# max    135563.000000    61.000000   223.000000   182.000000

# %%
### Number of Medals per Type

Summer_df['Medal'].value_counts()
# Out:
# Bronze    8566
# Gold      8542
# Silver    8233
# Name: Medal, dtype: int64

# %%
### Medals Won Per Team

Team_Medals = Summer_df.groupby('Team')['Medal'].nunique()
Team_Medals
# Out:
# Team
# Afghanistan                     1
# Algeria                         3
# Amateur Athletic Association    1
# Aphrodite                       1
# Argentina                       3
#                                ..
# Widgeon                         1
# Winnipeg Shamrocks-1            1
# Yugoslavia                      3
# Zambia                          1
# Zimbabwe                        3
# Name: Medal, Length: 246, dtype: int64

# %%
### Number of Athletes Per Team

Team_IDs = Summer_df.groupby('Team')['ID'].nunique()
Team_IDs
# Out:
# Team
# Afghanistan                       1
# Algeria                          12
# Amateur Athletic Association      2
# Aphrodite                         3
# Argentina                       173
#                                ...
# Widgeon                           2
# Winnipeg Shamrocks-1              2
# Yugoslavia                      256
# Zambia                            1
# Zimbabwe                         16
# Name: ID, Length: 246, dtype: int64

# %%
### Most Medals Won Per Team

Most_Team_Medals = Summer_df['Team'].value_counts()
Most_Team_Medals.head(25)
# Out:
# United States    3815
# Soviet Union     1864
# Germany          1246
# Australia        1182
# Great Britain     977
# Russia            883
# Italy             871
# France            843
# East Germany      841
# China             828
# Hungary           785
# Japan             779
# Romania           595
# Netherlands       590
# Canada            529
# Poland            519
# West Germany      498
# South Korea       447
# Spain             423
# Brazil            422
# Sweden            416
# Cuba              393
# Bulgaria          322
# Yugoslavia        314
# Finland           311
# Name: Team, dtype: int64

# %%
Most_Team_Medals = pd.DataFrame(Most_Team_Medals)
Most_Team_Medals.head(25)
# Out:
#                Team
# United States  3815
# Soviet Union   1864
# Germany        1246
# Australia      1182
# Great Britain   977
# Russia          883
# Italy           871
# France          843
# East Germany    841
# China           828
# Hungary         785
# Japan           779
# Romania         595
# Netherlands     590
# Canada          529
# Poland          519
# West Germany    498
# South Korea     447
# Spain           423
# Brazil          422
# Sweden          416
# Cuba            393
# Bulgaria        322
# Yugoslavia      314
# Finland         311

# %%
# Create a bar chart based off of the group series from before
Most_Team_Medals_Chart = Most_Team_Medals.head(10).plot(kind='bar', figsize=(20,9), rot=0, color='limegreen')

# Set the xlabel and ylabel using class methods
Most_Team_Medals_Chart.set_ylabel("Medals Won")
Most_Team_Medals_Chart.set_title("Total Medals Won - Team")

plt.show()
plt.tight_layout()

# %%
### All Male Medalists for All Teams

df_M = Summer_df.loc[df["Sex"] == "M", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

df_M.head()
# Out:
#    ID                     Name Sex   Age  Height  Weight     Team  \
# 1  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 2  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 3  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 4  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 5  17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
#
#          Games      City       Sport                                   Event  \
# 1  1948 Summer    London  Gymnastics  Gymnastics Men's Individual All-Around
# 2  1948 Summer    London  Gymnastics        Gymnastics Men's Team All-Around
# 3  1948 Summer    London  Gymnastics            Gymnastics Men's Horse Vault
# 4  1948 Summer    London  Gymnastics        Gymnastics Men's Pommelled Horse
# 5  1952 Summer  Helsinki  Gymnastics        Gymnastics Men's Team All-Around
#
#     Medal
# 1  Bronze
# 2    Gold
# 3    Gold
# 4    Gold
# 5  Bronze

# %%
df_M.describe()
# Out:
#                   ID           Age        Height        Weight
# count   16676.000000  16676.000000  16676.000000  16676.000000
# mean    69274.374430     25.769009    181.605061     79.324808
# std     38779.098071      5.051983     10.494088     14.473531
# min        17.000000     13.000000    140.000000     41.000000
# 25%     36506.500000     22.000000    175.000000     70.000000
# 50%     69286.500000     25.000000    182.000000     78.000000
# 75%    102977.250000     28.000000    188.000000     88.000000
# max    135554.000000     66.000000    223.000000    182.000000

# %%
### All Male Gold Medalists for All Teams

Gold_M = df_M.loc[df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_M.head()
# Out:
#     ID                              Name Sex   Age  Height  Weight     Team  \
# 2   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 3   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 4   17           Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 20  72  Aleksey Aleksandrovich Abalmasov   M  28.0   180.0    83.0  Belarus
# 21  73                         Luc Abalo   M  23.0   182.0    86.0   France
#
#           Games     City       Sport  \
# 2   1948 Summer   London  Gymnastics
# 3   1948 Summer   London  Gymnastics
# 4   1948 Summer   London  Gymnastics
# 20  2008 Summer  Beijing    Canoeing
# 21  2008 Summer  Beijing    Handball
#
#                                        Event Medal
# 2           Gymnastics Men's Team All-Around  Gold
# 3               Gymnastics Men's Horse Vault  Gold
# 4           Gymnastics Men's Pommelled Horse  Gold
# 20  Canoeing Men's Kayak Fours, 1,000 metres  Gold
# ...

# %%
Gold_M.describe()
# Out:
#                   ID          Age       Height       Weight
# count    5667.000000  5667.000000  5667.000000  5667.000000
# mean    69197.574731    25.688901   181.930651    79.640727
# std     38746.788839     5.030801    10.675192    14.541677
# min        17.000000    13.000000   140.000000    42.000000
# 25%     36323.000000    22.000000   175.000000    70.000000
# 50%     69210.000000    25.000000   182.000000    78.000000
# 75%    102867.000000    28.000000   189.000000    88.000000
# max    135545.000000    59.000000   223.000000   170.000000

# %%
### USA Gold Medalists

USA_Gold_M = Gold_M.loc[df["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

USA_Gold_M.head()
# Out:
#       ID                        Name Sex   Age  Height  Weight           Team  \
# 53   351  Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0  United States
# 64   423     Michael Brent Abernathy   M  22.0   182.0    84.0  United States
# 67   454   Edgar Allen "Ed" Ablowich   M  19.0   182.0    68.0  United States
# 130  836                 Platt Adams   M  27.0   188.0    78.0  United States
# 149  963        Derrick Ralph Adkins   M  26.0   188.0    80.0  United States
#
#            Games         City       Sport  \
# 53   2000 Summer       Sydney  Basketball
# 64   2000 Summer       Sydney    Baseball
# 67   1932 Summer  Los Angeles   Athletics
# 130  1912 Summer    Stockholm   Athletics
# 149  1996 Summer      Atlanta   Athletics
#
#                                     Event Medal
# 53            Basketball Men's Basketball  Gold
# 64                Baseball Men's Baseball  Gold
# 67   Athletics Men's 4 x 400 metres Relay  Gold
# ...

# %%
USA_Gold_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1233 entries, 53 to 30098
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1233 non-null   int64
#  1   Name    1233 non-null   object
#  2   Sex     1233 non-null   object
#  3   Age     1233 non-null   float64
#  4   Height  1233 non-null   float64
#  5   Weight  1233 non-null   float64
#  6   Team    1233 non-null   object
#  7   Games   1233 non-null   object
#  8   City    1233 non-null   object
#  9   Sport   1233 non-null   object
#  10  Event   1233 non-null   object
#  11  Medal   1233 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 125.2+ KB

# %%
USA_Gold_M['Name'].value_counts().head(10)
# Out:
# Michael Fred Phelps, II            23
# Raymond Clarence "Ray" Ewry        10
# Frederick Carlton "Carl" Lewis      9
# Mark Andrew Spitz                   9
# Matthew Nicholas "Matt" Biondi      8
# Donald Arthur "Don" Schollander     7
# Ryan Steven Lochte                  6
# Gary Wayne Hall, Jr.                5
# Nathan Ghar-Jun Adrian              5
# Martin Joseph Sheridan              5
# Name: Name, dtype: int64

# %%
USA_Gold_M_Name = USA_Gold_M['Name'].value_counts()
USA_Gold_M_Name = pd.DataFrame(USA_Gold_M_Name)
USA_Gold_M_Name.head()
# Out:
#                                 Name
# Michael Fred Phelps, II           23
# Raymond Clarence "Ray" Ewry       10
# Frederick Carlton "Carl" Lewis     9
# Mark Andrew Spitz                  9
# Matthew Nicholas "Matt" Biondi     8

# %%
# Create a bar chart based off of the group series from before
USA_Gold_M_Name_Chart = USA_Gold_M_Name.head(5).plot(kind='bar', figsize=(16,9), rot=0, color='gold')

# Set the xlabel and ylabel using class methods
USA_Gold_M_Name_Chart.set_ylabel("Medals Won")
USA_Gold_M_Name_Chart.set_title("USA Men's Gold Medals - Athlete Name")
plt.savefig('USA_Gold_M_Name.png')
plt.show()
plt.tight_layout()

# %%
USA_Gold_M['Sport'].value_counts()
# Out:
# Athletics        400
# Swimming         334
# Basketball       186
# Rowing            74
# Volleyball        36
# Boxing            36
# Wrestling         34
# Baseball          24
# Sailing           21
# Equestrianism     16
# Shooting          15
# Diving            13
# Gymnastics        11
# Weightlifting      9
# Archery            8
# Cycling            5
# Canoeing           4
# Tennis             3
# Taekwondo          2
# Rugby              2
# Name: Sport, dtype: int64

# %%
USA_Gold_M_Sports = USA_Gold_M['Sport'].value_counts()

# %%
USA_Gold_M_df = pd.DataFrame(USA_Gold_M_Sports)
USA_Gold_M_df.head()
# Out:
#             Sport
# Athletics     400
# Swimming      334
# Basketball    186
# Rowing         74
# Volleyball     36

# %%
ax = USA_Gold_M_df.head(5).plot.bar(y='Sport', rot=0)

# %%
### All Male Silver Medalists for All Teams

Silver_M = df_M.loc[df_M["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_M.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight           Team  \
# 14   30      Pepijn Aardewijn   M  26.0   189.0    72.0    Netherlands
# 23   73             Luc Abalo   M  31.0   182.0    86.0         France
# 26   84  Stephen Anthony Abas   M  26.0   165.0    55.0  United States
# 31   99             Pter Abay   M  30.0   181.0    79.0        Hungary
# 37  107     Carmine Abbagnale   M  30.0   182.0    90.0          Italy
#
#           Games            City      Sport  \
# 14  1996 Summer         Atlanta     Rowing
# 23  2016 Summer  Rio de Janeiro   Handball
# 26  2004 Summer          Athina  Wrestling
# 31  1992 Summer       Barcelona    Fencing
# 37  1992 Summer       Barcelona     Rowing
#
#                                        Event   Medal
# 14    Rowing Men's Lightweight Double Sculls  Silver
# 23                   Handball Men's Handball  Silver
# 26  Wrestling Men's Featherweight, Freestyle  Silver
# 31                 Fencing Men's Sabre, Team  Silver
# ...

# %%
### USA Silver Medalists

USA_Silver_M = Silver_M.loc[Silver_M["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Silver_M.head()
# Out:
#        ID                           Name Sex   Age  Height  Weight  \
# 26     84           Stephen Anthony Abas   M  26.0   165.0    55.0
# 124   807   Benjamin Willard "Ben" Adams   M  22.0   188.0    78.0
# 131   836                    Platt Adams   M  27.0   188.0    78.0
# 159  1017         Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
# 344  2387  David Donald "Dave" Albritton   M  23.0   191.0    79.0
#
#               Team        Games       City      Sport  \
# 26   United States  2004 Summer     Athina  Wrestling
# 124  United States  1912 Summer  Stockholm  Athletics
# 131  United States  1912 Summer  Stockholm  Athletics
# 159  United States  2012 Summer     London   Swimming
# 344  United States  1936 Summer     Berlin  Athletics
#
#                                              Event   Medal
# 26        Wrestling Men's Featherweight, Freestyle  Silver
# 124             Athletics Men's Standing High Jump  Silver
# ...

# %%
USA_Silver_M['Name'].value_counts()
# Out:
# John Michael Plumb                   4
# Kevin John Freeman                   3
# Ryan Steven Lochte                   3
# Michael Fred Phelps, II              3
# Martin Joseph Sheridan               3
#                                     ..
# Erin Wesley Hartwell                 1
# Jason Newth Morris                   1
# Matthew MacKenzie "Mack" Robinson    1
# Albert "Al" Robinson                 1
# William Edward "Ed" Ratleff          1
# Name: Name, Length: 569, dtype: int64

# %%
USA_Silver_M_Name = USA_Silver_M['Name'].value_counts()
USA_Silver_M_Name = pd.DataFrame(USA_Silver_M_Name)
USA_Silver_M_Name.head()
# Out:
#                          Name
# John Michael Plumb          4
# Kevin John Freeman          3
# Ryan Steven Lochte          3
# Michael Fred Phelps, II     3
# Martin Joseph Sheridan      3

# %%
# Create a bar chart based off of the group series from before
USA_Silver_M_Name_Chart = USA_Silver_M_Name.head(5).plot(kind='bar', figsize=(20,9), rot=0, color='silver')

# Set the xlabel and ylabel using class methods
USA_Silver_M_Name_Chart.set_ylabel("Medals Won")
USA_Silver_M_Name_Chart.set_title("USA Men's Silver Medals - Athlete Name")
plt.savefig('USA_Silver_M_Name.png')
plt.show()
plt.tight_layout()

# %%
### All Male Bronze Medalists for All Teams

Bronze_M = df_M.loc[df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_M.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  \
# 1   17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland
# 5   17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland
# 16  62        Giovanni Abagnale   M  21.0   198.0    90.0    Italy
# 17  63      Jos Luis Abajo Gmez   M  30.0   194.0    87.0    Spain
# 28  86  Jos Manuel Abascal Gmez   M  26.0   182.0    67.0    Spain
#
#           Games            City       Sport  \
# 1   1948 Summer          London  Gymnastics
# 5   1952 Summer        Helsinki  Gymnastics
# 16  2016 Summer  Rio de Janeiro      Rowing
# 17  2008 Summer         Beijing     Fencing
# 28  1984 Summer     Los Angeles   Athletics
#
#                                      Event   Medal
# 1   Gymnastics Men's Individual All-Around  Bronze
# 5         Gymnastics Men's Team All-Around  Bronze
# 16              Rowing Men's Coxless Pairs  Bronze
# 17          Fencing Men's epee, Individual  Bronze
# ...

# %%
### USA Bronze Medalists

USA_Bronze_M = Bronze_M.loc[Bronze_M["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Bronze_M.head()
# Out:
#        ID                          Name Sex   Age  Height  Weight  \
# 125   807  Benjamin Willard "Ben" Adams   M  22.0   188.0    78.0
# 161  1017        Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 162  1017        Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 422  2833               John Chad Allen   M  21.0   185.0    86.0
# 428  2874                   Wyatt Allen   M  29.0   193.0    98.0
#
#               Team        Games            City      Sport  \
# 125  United States  1912 Summer       Stockholm  Athletics
# 161  United States  2016 Summer  Rio de Janeiro   Swimming
# 162  United States  2016 Summer  Rio de Janeiro   Swimming
# 422  United States  1996 Summer         Atlanta   Baseball
# 428  United States  2008 Summer         Beijing     Rowing
#
#                                    Event   Medal
# 125   Athletics Men's Standing Long Jump  Bronze
# 161   Swimming Men's 50 metres Freestyle  Bronze
# 162  Swimming Men's 100 metres Freestyle  Bronze
# ...

# %%
USA_Bronze_M['Name'].value_counts()
# Out:
# Robert Jeffrey Dover                    4
# Ryan Steven Lochte                      3
# Guenter H. Seidel                       3
# George Thomas Breen                     3
# Michael Fred Phelps, II                 2
#                                        ..
# Murphy Edward Troy                      1
# Neal Shapiro                            1
# William Ronald "Bill" Forrester, Jr.    1
# David Maurice Robinson                  1
# James Michael "Jim" Martinez            1
# Name: Name, Length: 493, dtype: int64

# %%
USA_Bronze_M_Name = USA_Bronze_M['Name'].value_counts()
USA_Bronze_M_Name = pd.DataFrame(USA_Bronze_M_Name)
USA_Bronze_M_Name.head()
# Out:
#                          Name
# Robert Jeffrey Dover        4
# Ryan Steven Lochte          3
# Guenter H. Seidel           3
# George Thomas Breen         3
# Michael Fred Phelps, II     2

# %%
# Create a bar chart based off of the group series from before
USA_Bronze_M_Name_Chart = USA_Bronze_M_Name.head(5).plot(kind='bar', figsize=(20,9), rot=0, color='#b08d57')

# Set the xlabel and ylabel using class methods
USA_Bronze_M_Name_Chart.set_ylabel("Medals Won")
USA_Bronze_M_Name_Chart.set_title("USA Men's Bronze Medals - Athlete Name")
plt.savefig('USA_Bronze_M_Name.png')
plt.show()
plt.tight_layout()

# %%
# All Female Medalists for All Teams

df_F = Summer_df.loc[df["Sex"] == "F", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]


df_F.head()
# Out:
#      ID                                     Name Sex   Age  Height  Weight  \
# 15   37                       Ann Kristin Aarnes   F  23.0   182.0    64.0
# 18   65                        Patimat Abakarova   F  21.0   165.0    49.0
# 19   67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 29   90                Tamila Rashidovna Abasova   F  21.0   163.0    60.0
# 43  153                    Monica Cecilia Abbott   F  23.0   191.0    88.0
#
#              Team        Games            City      Sport  \
# 15         Norway  1996 Summer         Atlanta   Football
# 18     Azerbaijan  2016 Summer  Rio de Janeiro  Taekwondo
# 19         Russia  2008 Summer         Beijing  Athletics
# 29         Russia  2004 Summer          Athina    Cycling
# 43  United States  2008 Summer         Beijing   Softball
#
#                               Event   Medal
# 15        Football Women's Football  Bronze
# 18      Taekwondo Women's Flyweight  Bronze
# ...

# %%
df_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    8665.000000  8665.000000  8665.000000  8665.000000
# mean    71678.887017    24.448240   171.150606    63.577669
# std     39214.876979     5.141478     9.297549    11.092356
# min        37.000000    13.000000   136.000000    28.000000
# 25%     37871.000000    21.000000   165.000000    57.000000
# 50%     70863.000000    24.000000   171.000000    63.000000
# 75%    107113.000000    27.000000   177.000000    70.000000
# max    135563.000000    52.000000   210.000000   167.000000

# %%
### All Female Gold Medalists for All Teams

Gold_F = df_F.loc[df["Medal"] == "Gold", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Gold_F.head()
# Out:
#       ID                                  Name Sex   Age  Height  Weight  \
# 128  832                 Nicola Virginia Adams   F  29.0   164.0    51.0
# 129  832                 Nicola Virginia Adams   F  33.0   164.0    51.0
# 134  846  Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0   120.0
# 135  846  Valerie Kasanita Adams-Vili (-Price)   F  27.0   193.0   120.0
# 145  925   Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
#
#               Team        Games            City       Sport  \
# 128  Great Britain  2012 Summer          London      Boxing
# 129  Great Britain  2016 Summer  Rio de Janeiro      Boxing
# 134    New Zealand  2008 Summer         Beijing   Athletics
# 135    New Zealand  2012 Summer          London   Athletics
# 145         Brazil  2012 Summer          London  Volleyball
#
#                              Event Medal
# 128       Boxing Women's Flyweight  Gold
# 129       Boxing Women's Flyweight  Gold
# ...

# %%
Gold_F.describe()
# Out:
#                   ID          Age       Height       Weight
# count    2875.000000  2875.000000  2875.000000  2875.000000
# mean    71710.646261    24.236522   171.408696    63.795652
# std     39645.168332     5.100765     9.460514    11.442972
# min       832.000000    13.000000   136.000000    28.000000
# 25%     36582.000000    21.000000   165.000000    57.000000
# 50%     71584.000000    24.000000   172.000000    63.000000
# 75%    107749.500000    27.000000   178.000000    70.000000
# max    135553.000000    47.000000   210.000000   136.000000

# %%
### USA Gold Medalists - Female

USA_Gold_F = Gold_F.loc[df["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

USA_Gold_F.head()
# Out:
#        ID                                             Name Sex   Age  Height  \
# 215  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 217  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 273  1622                              Michelle Anne Akers   F  30.0   178.0
# 292  1682                                Morolake Akinosun   F  22.0   163.0
# 436  2929                      Lynne Marie Allsup (-Olson)   F  15.0   163.0
#
#      Weight           Team        Games            City      Sport  \
# 215    52.0  United States  1992 Summer       Barcelona   Swimming
# 217    52.0  United States  1992 Summer       Barcelona   Swimming
# 273    68.0  United States  1996 Summer         Atlanta   Football
# 292    61.0  United States  2016 Summer  Rio de Janeiro  Athletics
# 436    59.0  United States  1964 Summer           Tokyo   Swimming
#
#                                                Event Medal
# ...

# %%
USA_Gold_F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 716 entries, 215 to 29653
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      716 non-null    int64
#  1   Name    716 non-null    object
#  2   Sex     716 non-null    object
#  3   Age     716 non-null    float64
#  4   Height  716 non-null    float64
#  5   Weight  716 non-null    float64
#  6   Team    716 non-null    object
#  7   Games   716 non-null    object
#  8   City    716 non-null    object
#  9   Sport   716 non-null    object
#  10  Event   716 non-null    object
#  11  Medal   716 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 72.7+ KB

# %%
USA_Gold_F['Name'].value_counts()
# Out:
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    8
# Allyson Michelle Felix                             6
# Amy Deloris Van Dyken (-Rouen)                     6
# Kathleen Genevieve "Katie" Ledecky                 5
# Dana Whitney Vollmer (-Grant)                      5
#                                                   ..
# Harriet Claiborne Bland (-Green)                   1
# Andrea Lane Lloyd (-Curry)                         1
# Tairia Flowers                                     1
# Susan Elizabeth Doerr                              1
# Suzannah Bianco                                    1
# Name: Name, Length: 461, dtype: int64

# %%
USA_Gold_F_Name = USA_Gold_F['Name'].value_counts()
USA_Gold_F_Name = pd.DataFrame(USA_Gold_F_Name)
USA_Gold_F_Name.head()
# Out:
#                                                  Name
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     8
# Allyson Michelle Felix                              6
# Amy Deloris Van Dyken (-Rouen)                      6
# Kathleen Genevieve "Katie" Ledecky                  5
# Dana Whitney Vollmer (-Grant)                       5

# %%
# Create a bar chart based off of the group series from before
USA_Gold_F_Name_Chart = USA_Gold_F_Name.head(5).plot(kind='bar', figsize=(20,9), rot=0, color='gold')

# Set the xlabel and ylabel using class methods
USA_Gold_F_Name_Chart.set_ylabel("Medals Won")
USA_Gold_F_Name_Chart.set_title("USA Men's Gold Medals - Sport")
plt.savefig('USA_Gold_F_Name.png')
plt.show()
plt.tight_layout()

# %%
USA_Gold_F['Sport'].value_counts()
# Out:
# Swimming                 231
# Athletics                128
# Basketball                95
# Football                  66
# Softball                  38
# Rowing                    36
# Gymnastics                26
# Water Polo                25
# Synchronized Swimming     16
# Tennis                    12
# Diving                     9
# Shooting                   8
# Equestrianism              8
# Cycling                    4
# Sailing                    3
# Fencing                    2
# Archery                    2
# Judo                       2
# Boxing                     2
# Triathlon                  1
# Wrestling                  1
# Weightlifting              1
# Name: Sport, dtype: int64

# %%
USA_Gold_F_Sports = USA_Gold_F['Sport'].value_counts()

# %%
USA_Gold_F_df = pd.DataFrame(USA_Gold_F_Sports)
USA_Gold_F_df.head()
# Out:
#             Sport
# Swimming      231
# Athletics     128
# Basketball     95
# Football       66
# Softball       38

# %%
ax = USA_Gold_F_df.head(5).plot.bar(y='Sport', rot=0)

# %%
### All Female Silver Medalists for All Teams

Silver_F = df_F.loc[df["Medal"] == "Silver", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Silver_F.head()
# Out:
#      ID                                     Name Sex   Age  Height  Weight  \
# 19   67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 29   90                Tamila Rashidovna Abasova   F  21.0   163.0    60.0
# 43  153                    Monica Cecilia Abbott   F  23.0   191.0    88.0
# 44  165                      Nia Nicole Abdallah   F  20.0   175.0    56.0
# 59  394                               Irene Abel   F  19.0   160.0    48.0
#
#              Team        Games     City       Sport  \
# 19         Russia  2008 Summer  Beijing   Athletics
# 29         Russia  2004 Summer   Athina     Cycling
# 43  United States  2008 Summer  Beijing    Softball
# 44  United States  2004 Summer   Athina   Taekwondo
# 59   East Germany  1972 Summer   Munich  Gymnastics
#
#                                  Event   Medal
# 19     Athletics Women's Javelin Throw  Silver
# 29              Cycling Women's Sprint  Silver
# 43           Softball Women's Softball  Silver
# ...

# %%
### USA Silver Medalists - Female

USA_Silver_F = Silver_F.loc[Silver_F["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Silver_F.head()
# Out:
#        ID                                             Name Sex   Age  Height  \
# 43    153                            Monica Cecilia Abbott   F  23.0   191.0
# 44    165                              Nia Nicole Abdallah   F  20.0   175.0
# 203  1313                     Robyn Mokihana Ah Mow-Santos   F  32.0   172.0
# 216  1380  Christine M. "Crissy" Ahmann-Leighton (-Perham)   F  22.0   172.0
# 293  1683                       Foluke Antinuke Akinradewo   F  24.0   191.0
#
#      Weight           Team        Games       City       Sport  \
# 43     88.0  United States  2008 Summer    Beijing    Softball
# 44     56.0  United States  2004 Summer     Athina   Taekwondo
# 203    67.0  United States  2008 Summer    Beijing  Volleyball
# 216    52.0  United States  1992 Summer  Barcelona    Swimming
# 293    79.0  United States  2012 Summer     London  Volleyball
#
#                                      Event   Medal
# 43               Softball Women's Softball  Silver
# ...

# %%
USA_Silver_F['Name'].value_counts()
# Out:
# Shirley Frances Babashoff               6
# Sarah Kathryn Hammer (-Sparks)          4
# Amanda Ray Beard (-Brown)               4
# Dara Grace Torres (-Hoffman, -Minas)    4
# Natalie Anne Coughlin (-Hall)           4
#                                        ..
# Carmelita Jeter                         1
# Caryn Davies                            1
# Brandi Denise Chastain                  1
# Lauren Tamayo (Franges-)                1
# Lindsay H. Burns                        1
# Name: Name, Length: 326, dtype: int64

# %%
USA_Silver_F_Name = USA_Silver_F['Name'].value_counts()
USA_Silver_F_Name = pd.DataFrame(USA_Silver_F_Name)
USA_Silver_F_Name.head()
# Out:
#                                       Name
# Shirley Frances Babashoff                6
# Sarah Kathryn Hammer (-Sparks)           4
# Amanda Ray Beard (-Brown)                4
# Dara Grace Torres (-Hoffman, -Minas)     4
# Natalie Anne Coughlin (-Hall)            4

# %%
# Create a bar chart based off of the group series from before
USA_Silver_F_Name_Chart = USA_Silver_F_Name.head(5).plot(kind='bar', figsize=(20,9), rot=0, color='silver')

# Set the xlabel and ylabel using class methods
USA_Silver_F_Name_Chart.set_ylabel("Medals Won")
USA_Silver_F_Name_Chart.set_title("USA Men's Gold Medals - Sport")
plt.savefig('USA_Silver_F_Name.png')
plt.show()
plt.tight_layout()

# %%
### All Female Bronze Medalists for All Teams

Bronze_F = df_F.loc[df["Medal"] == "Bronze", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

Bronze_F.head()
# Out:
#      ID                          Name Sex   Age  Height  Weight        Team  \
# 15   37            Ann Kristin Aarnes   F  23.0   182.0    64.0      Norway
# 18   65             Patimat Abakarova   F  21.0   165.0    49.0  Azerbaijan
# 46  259                    Reema Abdo   F  21.0   173.0    59.0      Canada
# 60  395                 Jennifer Abel   F  20.0   160.0    62.0      Canada
# 89  580  Svetlana Olegovna Abrosimova   F  28.0   188.0    77.0      Russia
#
#           Games            City       Sport  \
# 15  1996 Summer         Atlanta    Football
# 18  2016 Summer  Rio de Janeiro   Taekwondo
# 46  1984 Summer     Los Angeles    Swimming
# 60  2012 Summer          London      Diving
# 89  2008 Summer         Beijing  Basketball
#
#                                            Event   Medal
# 15                     Football Women's Football  Bronze
# 18                   Taekwondo Women's Flyweight  Bronze
# 46  Swimming Women's 4 x 100 metres Medley Relay  Bronze
# ...

# %%
### USA Bronze Medalists - Female

USA_Bronze_F = Bronze_F.loc[Bronze_F["Team"] == "United States", [
    "ID", "Name", "Sex", "Age", "Height", "Weight", "Team", "Games", "City", "Sport", "Event", "Medal"]]

# %%
USA_Bronze_F.head()
# Out:
#        ID                              Name Sex   Age  Height  Weight  \
# 132   837              Rachael Alexis Adams   F  26.0   188.0    81.0
# 294  1683        Foluke Antinuke Akinradewo   F  28.0   191.0    79.0
# 299  1730                    Monica Aksamit   F  26.0   183.0    74.0
# 350  2443  Joan "Jody" Alderson (-Braskamp)   F  17.0   170.0    59.0
# 566  3681     Elizabeth Rambo "Beth" Anders   F  32.0   174.0    73.0
#
#               Team        Games            City       Sport  \
# 132  United States  2016 Summer  Rio de Janeiro  Volleyball
# 294  United States  2016 Summer  Rio de Janeiro  Volleyball
# 299  United States  2016 Summer  Rio de Janeiro     Fencing
# 350  United States  1952 Summer        Helsinki    Swimming
# 566  United States  1984 Summer     Los Angeles      Hockey
#
#                                                Event   Medal
# 132                    Volleyball Women's Volleyball  Bronze
# ...

# %%
USA_Bronze_F['Name'].value_counts()
# Out:
# Natalie Anne Coughlin (-Hall)                  5
# Dara Grace Torres (-Hoffman, -Minas)           4
# Shannon Lee Miller (-Phillips, -Falconetti)    3
# Dominique Margaux Dawes (-Thompson)            3
# Angelina L. "Angel" Martino (Myers-, -Sims)    3
#                                               ..
# Catherine Michelle "Katie" Meili               1
# Adrienne Elizabeth  Martelli                   1
# Passion J. Richardson                          1
# Tonja Yvette Buford-Bailey                     1
# Marcia Ingram Jones Smoke                      1
# Name: Name, Length: 269, dtype: int64

# %%
USA_Bronze_F_Name = USA_Bronze_F['Name'].value_counts()
USA_Bronze_F_Name = pd.DataFrame(USA_Bronze_F_Name)
USA_Bronze_F_Name.head()
# Out:
#                                              Name
# Natalie Anne Coughlin (-Hall)                   5
# Dara Grace Torres (-Hoffman, -Minas)            4
# Shannon Lee Miller (-Phillips, -Falconetti)     3
# Dominique Margaux Dawes (-Thompson)             3
# Angelina L. "Angel" Martino (Myers-, -Sims)     3

# %%
# Create a bar chart based off of the group series from before
USA_Bronze_F_Name_Chart = USA_Bronze_F_Name.head(5).plot(kind='bar', figsize=(20,9), rot=0, color='#b08d57')

# Set the xlabel and ylabel using class methods
USA_Bronze_F_Name_Chart.set_ylabel("Medals Won")
USA_Bronze_F_Name_Chart.set_title("USA Men's Gold Medals - Sport")
plt.savefig('USA_Bronze_F_Name.png')
plt.show()
plt.tight_layout()

# %%
### All USA Medalists

USA_df = Summer_df.loc[df["Team"] == "United States", :]
USA_df.head()
# Out:
#      ID                        Name Sex   Age  Height  Weight           Team  \
# 26   84        Stephen Anthony Abas   M  26.0   165.0    55.0  United States
# 43  153       Monica Cecilia Abbott   F  23.0   191.0    88.0  United States
# 44  165         Nia Nicole Abdallah   F  20.0   175.0    56.0  United States
# 53  351  Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0  United States
# 64  423     Michael Brent Abernathy   M  22.0   182.0    84.0  United States
#
#     NOC        Games  Year  Season     City       Sport  \
# 26  USA  2004 Summer  2004  Summer   Athina   Wrestling
# 43  USA  2008 Summer  2008  Summer  Beijing    Softball
# 44  USA  2004 Summer  2004  Summer   Athina   Taekwondo
# 53  USA  2000 Summer  2000  Summer   Sydney  Basketball
# 64  USA  2000 Summer  2000  Summer   Sydney    Baseball
#
#                                        Event   Medal
# 26  Wrestling Men's Featherweight, Freestyle  Silver
# 43                 Softball Women's Softball  Silver
# ...

# %%
USA_df['Medal'].value_counts()
# Out:
# Gold      1949
# Silver    1032
# Bronze     834
# Name: Medal, dtype: int64

# %%
USA_df['Sport'].value_counts().head()
# Out:
# Athletics     1004
# Swimming       917
# Basketball     341
# Rowing         265
# Volleyball     120
# Name: Sport, dtype: int64

# %%
### USA Men's Gold Analysis

USA_Gold_M['Medal'].value_counts()
# Out:
# Gold    1233
# Name: Medal, dtype: int64

# %%
USA_Gold_M['Sport'].value_counts()
# Out:
# Athletics        400
# Swimming         334
# Basketball       186
# Rowing            74
# Volleyball        36
# Boxing            36
# Wrestling         34
# Baseball          24
# Sailing           21
# Equestrianism     16
# Shooting          15
# Diving            13
# Gymnastics        11
# Weightlifting      9
# Archery            8
# Cycling            5
# Canoeing           4
# Tennis             3
# Taekwondo          2
# Rugby              2
# Name: Sport, dtype: int64

# %%
USA_Gold_M_Sports = USA_Gold_M['Sport'].value_counts()
USA_Gold_M_Sports = pd.DataFrame(USA_Gold_M_Sports)
USA_Gold_M_Sports.head()
# Out:
#             Sport
# Athletics     400
# Swimming      334
# Basketball    186
# Rowing         74
# Volleyball     36

# %%
ax = USA_Gold_M_Sports.head(5).plot.bar(y='Sport', rot=0)

# %%
# Create a bar chart based off of the group series from before
USA_Gold_M_Sports_Chart = USA_Gold_M_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='gold')

# Set the xlabel and ylabel using class methods
USA_Gold_M_Sports_Chart.set_ylabel("Medals Won")
USA_Gold_M_Sports_Chart.set_title("USA Men's Gold Medals - Sport")
plt.savefig('USA_Gold_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Men's Silver Analysis

USA_Silver_M['Medal'].value_counts()
# Out:
# Silver    643
# Name: Medal, dtype: int64

# %%
USA_Silver_M['Sport'].value_counts()
# Out:
# Athletics            222
# Swimming             103
# Rowing                64
# Water Polo            39
# Sailing               33
# Equestrianism         28
# Wrestling             24
# Boxing                13
# Gymnastics            13
# Weightlifting         13
# Diving                13
# Basketball            12
# Shooting              12
# Archery               11
# Ice Hockey            10
# Cycling               10
# Modern Pentathlon      9
# Fencing                6
# Judo                   4
# Tennis                 2
# Taekwondo              1
# Canoeing               1
# Name: Sport, dtype: int64

# %%
USA_Silver_M_Sports = USA_Silver_M['Sport'].value_counts()
USA_Silver_M_Sports = pd.DataFrame(USA_Silver_M_Sports)
USA_Silver_M_Sports.head()
# Out:
#             Sport
# Athletics     222
# Swimming      103
# Rowing         64
# Water Polo     39
# Sailing        33

# %%
ax = USA_Silver_M_Sports.head(5).plot.bar(y='Sport', rot=0)

# %%
# Create a bar chart based off of the group series from before
USA_Silver_M_Sports_Chart = USA_Silver_M_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='silver')

# Set the xlabel and ylabel using class methods
USA_Silver_M_Sports_Chart.set_ylabel("Medals Won")
USA_Silver_M_Sports_Chart.set_title("USA Men's Silver Medals - Sport")
plt.savefig('USA_Silver_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Men's Bronze Analysis

USA_Bronze_M['Medal'].value_counts()
# Out:
# Bronze    533
# Name: Medal, dtype: int64

# %%
USA_Bronze_M['Sport'].value_counts()
# Out:
# Athletics            157
# Swimming              68
# Rowing                45
# Baseball              44
# Boxing                26
# Volleyball            24
# Basketball            24
# Wrestling             19
# Equestrianism         19
# Sailing               17
# Diving                14
# Water Polo            11
# Gymnastics            11
# Shooting              10
# Fencing                9
# Cycling                8
# Judo                   6
# Weightlifting          5
# Archery                4
# Modern Pentathlon      4
# Canoeing               3
# Taekwondo              2
# Tennis                 1
# Hockey                 1
# Golf                   1
# Name: Sport, dtype: int64

# %%
USA_Bronze_M_Sports = USA_Bronze_M['Sport'].value_counts()
USA_Bronze_M_Sports = pd.DataFrame(USA_Bronze_M_Sports)
USA_Bronze_M_Sports.head()
# Out:
#            Sport
# Athletics    157
# Swimming      68
# Rowing        45
# Baseball      44
# Boxing        26

# %%
ax = USA_Bronze_M_Sports.head(5).plot.bar(y='Sport', rot=0)

# %%
# Create a bar chart based off of the group series from before
USA_Bronze_M_Sports_Chart = USA_Bronze_M_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='#b08d57')

# Set the xlabel and ylabel using class methods
USA_Bronze_M_Sports_Chart.set_ylabel("Medals Won")
USA_Bronze_M_Sports_Chart.set_title("USA Men's Bronze Medals - Sport")
plt.savefig('USA_Bronze_M_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Women's Gold Analysis

USA_Gold_F['Medal'].value_counts()
# Out:
# Gold    716
# Name: Medal, dtype: int64

# %%
USA_Gold_F['Sport'].value_counts()
# Out:
# Swimming                 231
# Athletics                128
# Basketball                95
# Football                  66
# Softball                  38
# Rowing                    36
# Gymnastics                26
# Water Polo                25
# Synchronized Swimming     16
# Tennis                    12
# Diving                     9
# Shooting                   8
# Equestrianism              8
# Cycling                    4
# Sailing                    3
# Fencing                    2
# Archery                    2
# Judo                       2
# Boxing                     2
# Triathlon                  1
# Wrestling                  1
# Weightlifting              1
# Name: Sport, dtype: int64

# %%
USA_Gold_F_Sports = USA_Gold_F['Sport'].value_counts()
USA_Gold_F_Sports = pd.DataFrame(USA_Gold_F_Sports)
USA_Gold_F_Sports.head()
# Out:
#             Sport
# Swimming      231
# Athletics     128
# Basketball     95
# Football       66
# Softball       38

# %%
ax = USA_Gold_F_Sports.head(5).plot.bar(y='Sport', rot=0)

# %%
# Create a bar chart based off of the group series from before
USA_Gold_F_Sports_Chart = USA_Gold_F_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='gold')

# Set the xlabel and ylabel using class methods
USA_Gold_F_Sports_Chart.set_ylabel("Medals Won")
USA_Gold_F_Sports_Chart.set_title("USA Women's Gold Medals - Sport")
plt.savefig('USA_Gold_F_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Women's Silver Analysis

USA_Silver_F['Medal'].value_counts()
# Out:
# Silver    389
# Name: Medal, dtype: int64

# %%
USA_Silver_F['Sport'].value_counts()
# Out:
# Swimming                 110
# Athletics                 60
# Volleyball                36
# Gymnastics                35
# Rowing                    27
# Water Polo                26
# Softball                  15
# Cycling                   14
# Football                  13
# Basketball                12
# Equestrianism             12
# Diving                    11
# Fencing                    4
# Synchronized Swimming      3
# Canoeing                   3
# Shooting                   3
# Sailing                    2
# Modern Pentathlon          1
# Taekwondo                  1
# Wrestling                  1
# Name: Sport, dtype: int64

# %%
USA_Silver_F_Sports = USA_Silver_F['Sport'].value_counts()
USA_Silver_F_Sports = pd.DataFrame(USA_Silver_F_Sports)
USA_Silver_F_Sports.head()
# Out:
#             Sport
# Swimming      110
# Athletics      60
# Volleyball     36
# Gymnastics     35
# Rowing         27

# %%
ax = USA_Silver_F_Sports.head(5).plot.bar(y='Sport', rot=0)

# %%
# Create a bar chart based off of the group series from before
USA_Silver_F_Sports_Chart = USA_Silver_F_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='silver')

# Set the xlabel and ylabel using class methods
USA_Silver_F_Sports_Chart.set_ylabel("Medals Won")
USA_Silver_F_Sports_Chart.set_title("USA Women's Silver Medals - Sport")
plt.savefig('USA_Silver_F_Sports.png')
plt.show()
plt.tight_layout()

# %%
### USA Women's Bronze Analysis

USA_Bronze_F['Medal'].value_counts()
# Out:
# Bronze    301
# Name: Medal, dtype: int64

# %%
USA_Bronze_F['Sport'].value_counts()
# Out:
# Swimming                 71
# Athletics                37
# Volleyball               24
# Gymnastics               22
# Rowing                   19
# Equestrianism            18
# Hockey                   16
# Fencing                  13
# Diving                   13
# Water Polo               12
# Basketball               12
# Synchronized Swimming    11
# Cycling                   5
# Shooting                  5
# Sailing                   4
# Taekwondo                 3
# Tennis                    3
# Archery                   3
# Wrestling                 3
# Weightlifting             2
# Judo                      2
# Canoeing                  1
# Boxing                    1
# Triathlon                 1
# Name: Sport, dtype: int64

# %%
USA_Bronze_F_Sports = USA_Bronze_F['Sport'].value_counts()
USA_Bronze_F_Sports = pd.DataFrame(USA_Bronze_F_Sports)
USA_Bronze_F_Sports.head()
# Out:
#             Sport
# Swimming       71
# Athletics      37
# Volleyball     24
# Gymnastics     22
# Rowing         19

# %%
# Create a bar chart based off of the group series from before
USA_Bronze_F_Sports_Chart = USA_Bronze_F_Sports.head(10).plot(kind='bar', figsize=(14,7), rot=0, color='#b08d57')

# Set the xlabel and ylabel using class methods
USA_Bronze_F_Sports_Chart.set_ylabel("Medals Won")
USA_Bronze_F_Sports_Chart.set_title("USA Women's Bronze Medals - Sport")
plt.savefig('USA_Bronze_F_Sports.png')
plt.show()
plt.tight_layout()
